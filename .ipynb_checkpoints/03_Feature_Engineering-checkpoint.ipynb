# %%
# %load_ext autotime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import pickle
# Out:
# time: 1.11 s (started: 2022-10-08 09:35:12 +08:00)

# %%
x = pickle.load(open('./data/fundamentals2.pkl', 'rb'))
y = pickle.load(open('./data/performance2.pkl', 'rb'))
# Out:
# time: 31 ms (started: 2022-10-08 09:35:14 +08:00)

# %%
print(x.shape)
print(y.shape)
# Out:
# (38307, 74)
# (38307, 7)
# time: 0 ns (started: 2022-10-08 09:35:14 +08:00)

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38307 entries, 0 to 38306
# Data columns (total 74 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Ticker                                           38307 non-null  object
#  1   Report Date                                      38307 non-null  datetime64[ns]
#  2   SimFinId                                         38307 non-null  int64
#  3   Currency                                         38307 non-null  object
#  4   Fiscal Year                                      38307 non-null  int64
#  5   Fiscal Period_x                                  38307 non-null  object
#  6   Publish Date                                     38307 non-null  datetime64[ns]
#  7   Restated Date_x                                  38307 non-null  datetime64[ns]
#  8   Shares (Basic)_x                                 38307 non-null  float64
#  9   Shares (Diluted)_x                               38307 non-null  float64
#  10  Revenue                                          37374 non-null  float64
#  11  Cost of Revenue                                  34484 non-null  float64
#  12  Gross Profit                                     34473 non-null  float64
#  13  Operating Expenses                               38255 non-null  float64
#  14  Selling, General & Administrative                36389 non-null  float64
#  15  Research & Development                           16413 non-null  float64
#  16  Depreciation & Amortization_x                    17235 non-null  float64
#  17  Operating Income (Loss)                          38306 non-null  float64
#  18  Non-Operating Income (Loss)                      38138 non-null  float64
#  19  Interest Expense, Net                            34275 non-null  float64
#  20  Pretax Income (Loss), Adj.                       38307 non-null  int64
#  21  Abnormal Gains (Losses)                          22222 non-null  float64
#  22  Pretax Income (Loss)                             38307 non-null  int64
#  23  Income Tax (Expense) Benefit, Net                34833 non-null  float64
#  24  Income (Loss) from Continuing Operations         38307 non-null  int64
#  25  Net Extraordinary Gains (Losses)                 4641 non-null   float64
#  26  Net Income                                       38307 non-null  int64
#  27  Net Income (Common)                              38307 non-null  int64
#  28  Fiscal Period_y                                  38307 non-null  object
#  29  Restated Date_y                                  38307 non-null  datetime64[ns]
#  30  Shares (Basic)_y                                 38307 non-null  float64
#  31  Shares (Diluted)_y                               38307 non-null  float64
#  32  Cash, Cash Equivalents & Short Term Investments  38202 non-null  float64
#  33  Accounts & Notes Receivable                      34758 non-null  float64
#  34  Inventories                                      25400 non-null  float64
#  35  Total Current Assets                             38307 non-null  float64
#  36  Property, Plant & Equipment, Net                 37732 non-null  float64
#  37  Long Term Investments & Receivables              9908 non-null   float64
#  38  Other Long Term Assets                           38035 non-null  float64
#  39  Total Noncurrent Assets                          38264 non-null  float64
#  40  Total Assets                                     38307 non-null  int64
#  41  Payables & Accruals                              38187 non-null  float64
#  42  Short Term Debt                                  24161 non-null  float64
#  43  Total Current Liabilities                        38307 non-null  int64
#  44  Long Term Debt                                   30695 non-null  float64
#  45  Total Noncurrent Liabilities                     37882 non-null  float64
#  46  Total Liabilities                                38307 non-null  int64
#  47  Share Capital & Additional Paid-In Capital       37780 non-null  float64
#  48  Treasury Stock                                   16825 non-null  float64
#  49  Retained Earnings                                36597 non-null  float64
#  50  Total Equity                                     38305 non-null  float64
#  51  Total Liabilities & Equity                       38307 non-null  int64
#  52  Fiscal Period                                    38307 non-null  object
#  53  Restated Date                                    38307 non-null  datetime64[ns]
#  54  Shares (Basic)                                   38307 non-null  float64
#  55  Shares (Diluted)                                 38307 non-null  float64
#  56  Net Income/Starting Line                         37838 non-null  float64
#  57  Depreciation & Amortization_y                    37382 non-null  float64
#  58  Non-Cash Items                                   37861 non-null  float64
#  59  Change in Working Capital                        37626 non-null  float64
#  60  Change in Accounts Receivable                    2775 non-null   float64
#  61  Change in Inventories                            2017 non-null   float64
#  62  Change in Accounts Payable                       2253 non-null   float64
#  63  Change in Other                                  3299 non-null   float64
#  64  Net Cash from Operating Activities               38305 non-null  float64
#  65  Change in Fixed Assets & Intangibles             37426 non-null  float64
#  66  Net Change in Long Term Investment               13878 non-null  float64
#  67  Net Cash from Acquisitions & Divestitures        17337 non-null  float64
#  68  Net Cash from Investing Activities               38092 non-null  float64
#  69  Dividends Paid                                   18018 non-null  float64
#  70  Cash from (Repayment of) Debt                    31873 non-null  float64
#  71  Cash from (Repurchase of) Equity                 31726 non-null  float64
#  72  Net Cash from Financing Activities               38108 non-null  float64
#  73  Net Change in Cash                               38307 non-null  int64
# dtypes: datetime64[ns](5), float64(52), int64(12), object(5)
# memory usage: 21.6+ MB
# time: 16 ms (started: 2022-10-08 09:35:14 +08:00)

# %% [markdown]
# As there are still some null values, we would need to fix these as any feature engineered ratio could give us an error. Let's fill these null values with zero first.

# %%
x = x.fillna(0)
# Out:
# time: 672 ms (started: 2022-10-08 09:35:14 +08:00)

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38307 entries, 0 to 38306
# Data columns (total 74 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Ticker                                           38307 non-null  object
#  1   Report Date                                      38307 non-null  datetime64[ns]
#  2   SimFinId                                         38307 non-null  int64
#  3   Currency                                         38307 non-null  object
#  4   Fiscal Year                                      38307 non-null  int64
#  5   Fiscal Period_x                                  38307 non-null  object
#  6   Publish Date                                     38307 non-null  datetime64[ns]
#  7   Restated Date_x                                  38307 non-null  datetime64[ns]
#  8   Shares (Basic)_x                                 38307 non-null  float64
#  9   Shares (Diluted)_x                               38307 non-null  float64
#  10  Revenue                                          38307 non-null  float64
#  11  Cost of Revenue                                  38307 non-null  float64
#  12  Gross Profit                                     38307 non-null  float64
#  13  Operating Expenses                               38307 non-null  float64
#  14  Selling, General & Administrative                38307 non-null  float64
#  15  Research & Development                           38307 non-null  float64
#  16  Depreciation & Amortization_x                    38307 non-null  float64
#  17  Operating Income (Loss)                          38307 non-null  float64
#  18  Non-Operating Income (Loss)                      38307 non-null  float64
#  19  Interest Expense, Net                            38307 non-null  float64
#  20  Pretax Income (Loss), Adj.                       38307 non-null  int64
#  21  Abnormal Gains (Losses)                          38307 non-null  float64
#  22  Pretax Income (Loss)                             38307 non-null  int64
#  23  Income Tax (Expense) Benefit, Net                38307 non-null  float64
#  24  Income (Loss) from Continuing Operations         38307 non-null  int64
#  25  Net Extraordinary Gains (Losses)                 38307 non-null  float64
#  26  Net Income                                       38307 non-null  int64
#  27  Net Income (Common)                              38307 non-null  int64
#  28  Fiscal Period_y                                  38307 non-null  object
#  29  Restated Date_y                                  38307 non-null  datetime64[ns]
#  30  Shares (Basic)_y                                 38307 non-null  float64
#  31  Shares (Diluted)_y                               38307 non-null  float64
#  32  Cash, Cash Equivalents & Short Term Investments  38307 non-null  float64
#  33  Accounts & Notes Receivable                      38307 non-null  float64
#  34  Inventories                                      38307 non-null  float64
#  35  Total Current Assets                             38307 non-null  float64
#  36  Property, Plant & Equipment, Net                 38307 non-null  float64
#  37  Long Term Investments & Receivables              38307 non-null  float64
#  38  Other Long Term Assets                           38307 non-null  float64
#  39  Total Noncurrent Assets                          38307 non-null  float64
#  40  Total Assets                                     38307 non-null  int64
#  41  Payables & Accruals                              38307 non-null  float64
#  42  Short Term Debt                                  38307 non-null  float64
#  43  Total Current Liabilities                        38307 non-null  int64
#  44  Long Term Debt                                   38307 non-null  float64
#  45  Total Noncurrent Liabilities                     38307 non-null  float64
#  46  Total Liabilities                                38307 non-null  int64
#  47  Share Capital & Additional Paid-In Capital       38307 non-null  float64
#  48  Treasury Stock                                   38307 non-null  float64
#  49  Retained Earnings                                38307 non-null  float64
#  50  Total Equity                                     38307 non-null  float64
#  51  Total Liabilities & Equity                       38307 non-null  int64
#  52  Fiscal Period                                    38307 non-null  object
#  53  Restated Date                                    38307 non-null  datetime64[ns]
#  54  Shares (Basic)                                   38307 non-null  float64
#  55  Shares (Diluted)                                 38307 non-null  float64
#  56  Net Income/Starting Line                         38307 non-null  float64
#  57  Depreciation & Amortization_y                    38307 non-null  float64
#  58  Non-Cash Items                                   38307 non-null  float64
#  59  Change in Working Capital                        38307 non-null  float64
#  60  Change in Accounts Receivable                    38307 non-null  float64
#  61  Change in Inventories                            38307 non-null  float64
#  62  Change in Accounts Payable                       38307 non-null  float64
#  63  Change in Other                                  38307 non-null  float64
#  64  Net Cash from Operating Activities               38307 non-null  float64
#  65  Change in Fixed Assets & Intangibles             38307 non-null  float64
#  66  Net Change in Long Term Investment               38307 non-null  float64
#  67  Net Cash from Acquisitions & Divestitures        38307 non-null  float64
#  68  Net Cash from Investing Activities               38307 non-null  float64
#  69  Dividends Paid                                   38307 non-null  float64
#  70  Cash from (Repayment of) Debt                    38307 non-null  float64
#  71  Cash from (Repurchase of) Equity                 38307 non-null  float64
#  72  Net Cash from Financing Activities               38307 non-null  float64
#  73  Net Change in Cash                               38307 non-null  int64
# dtypes: datetime64[ns](5), float64(52), int64(12), object(5)
# memory usage: 21.6+ MB
# time: 16 ms (started: 2022-10-08 09:35:14 +08:00)

# %%
# Add in two new columns
# Market Cap = Shares (Diluted)_x  x Open Price
# EV = Market cap + LT debt + ST debt - Cash
# EBIT = Net Income - Interest Expense - Income Tax (Expense) Benefit, Net

x['Market Cap'] = x['Shares (Diluted)_x'] * y['Open1']
x['EV'] = x['Market Cap'] + x['Long Term Debt'] + x['Short Term Debt'] - x['Cash, Cash Equivalents & Short Term Investments']
x['EBIT'] = x['Net Income'] - x['Interest Expense, Net'] - x['Income Tax (Expense) Benefit, Net']
# Out:
# time: 0 ns (started: 2022-10-08 09:35:14 +08:00)

# %%
x.head()
# Out:
#   Ticker Report Date  SimFinId Currency  Fiscal Year Fiscal Period_x  \
# 0      A  2016-10-31     45846      USD         2016              Q4
# 1      A  2017-01-31     45846      USD         2017              Q1
# 2      A  2017-04-30     45846      USD         2017              Q2
# 3      A  2017-07-31     45846      USD         2017              Q3
# 4      A  2017-10-31     45846      USD         2017              Q4
#
#   Publish Date Restated Date_x  Shares (Basic)_x  Shares (Diluted)_x  ...  \
# 0   2016-12-20      2018-12-20       324000000.0         328000000.0  ...
# 1   2017-03-08      2018-03-06       322000000.0         326000000.0  ...
# 2   2017-06-06      2018-05-31       321000000.0         325000000.0  ...
# 3   2017-09-06      2018-08-30       321000000.0         326000000.0  ...
# 4   2017-12-21      2018-12-20       324000000.0         327000000.0  ...
#
#    Net Cash from Acquisitions & Divestitures  \
# 0                                -26000000.0
# 1                                -69000000.0
# 2                                        0.0
# 3                                -57000000.0
# 4                                        0.0
#
#    Net Cash from Investing Activities  Dividends Paid  \
# 0                         -78000000.0     -38000000.0
# 1                        -101000000.0     -42000000.0
# 2                         -43000000.0     -43000000.0
# 3                        -101000000.0     -42000000.0
# 4                         -60000000.0     -43000000.0
#
#    Cash from (Repayment of) Debt  Cash from (Repurchase of) Equity  \
# 0                     27000000.0                       -43000000.0
# 1                     89000000.0                       -93000000.0
# 2                     52000000.0                       -75000000.0
# 3                     39000000.0                        32000000.0
# 4                    -70000000.0                         8000000.0
#
#    Net Cash from Financing Activities  Net Change in Cash    Market Cap  \
# 0                         -56000000.0            90000000  1.421224e+10
# 1                         -58000000.0           -48000000  1.566104e+10
# 2                         -67000000.0           148000000  1.803750e+10
# 3                          29000000.0           174000000  1.966432e+10
# 4                        -106000000.0           115000000  2.215098e+10
#
#              EV         EBIT
# 0  1.382724e+10  167000000.0
# 1  1.541204e+10  209000000.0
# 2  1.769150e+10  206000000.0
# 3  1.918232e+10  206000000.0
# 4  2.148398e+10  239000000.0
#
# [5 rows x 77 columns]
# time: 16 ms (started: 2022-10-08 09:35:14 +08:00)

# %%
# Create a function to feature engineer many different financial ratios
# Takes in original fundamental dataframe then output all the ratio

def getRatios(df):    
    # Create a new dataframe to copy ratios into
    df1 = pd.DataFrame()
    
    # EV/EBIT
    df1['EV_EBIT'] = df['EV']/df['EBIT']

    # Operating Income over (Net working capital + Fidfed assets)
    df1['OI_NWCFA'] = df['Operating Income (Loss)']/\
    (df['Total Current Assets'] - df['Total Current Liabilities'] + df['Property, Plant & Equipment, Net'])

    # Price to earnings
    df1['PE'] = df['Market Cap']/df['Net Income']

    # Price to book
    df1['PB'] = df['Market Cap']/df['Total Equity']

    # Price to sales
    df1['PS'] = df['Market Cap']/df['Revenue']

    # Operating Income over Interest Edfpense
    df1['OI_IntExp'] = df['Operating Income (Loss)']/ -df['Interest Expense, Net']

    # Working Capital Ratio (CA/CL)
    df1['WorkingCap'] = df['Total Current Assets']/ df['Total Current Liabilities']

    # Return on Equity
    df1['ROE'] = df['Net Income']/ df['Total Equity']

    # Return on Capital Employed
    df1['ROCE'] = df['EBIT']/ (df['Total Assets'] - df['Total Current Liabilities'])

    # Debt/Equity
    df1['DE'] = df['Total Liabilities']/ df['Total Equity']

    # Debt Ratio
    df1['DebtRatio'] = df['Total Assets']/ df['Total Liabilities']

    # Cash Ratio
    df1['CashRatio'] = df['Cash, Cash Equivalents & Short Term Investments']/ df['Total Current Liabilities']

    # Asset Turnover
    df1['AssetTurnover'] = df['Revenue']/ df['Property, Plant & Equipment, Net']

    # Gross Profit Margin
    df1['GPM'] = df['Gross Profit']/ df['Revenue']

    # Working Capital over total assets
    df1['WC_TA'] = (df['Total Current Assets'] - df['Total Current Liabilities'])/ df['Total Assets']

    # Retained earnings over total assets
    df1['RE_TA'] = df['Retained Earnings']/ df['Total Assets']

    # EBIT over total assets
    df1['EBIT_TA'] = df['EBIT']/ df['Total Assets']

    # Equity over liabilities
    df1['Equity_Liab'] = df['Total Equity']/ df['Total Liabilities']
    
    return df1
# Out:
# time: 0 ns (started: 2022-10-08 09:35:14 +08:00)

# %%
def fixRatios(df):
    '''
    Takes in df, edits it to have the distributions clipped.
    The distribution clippings are done manually by eye,
    with human judgement based on the information.
    '''
    df["ROE"].clip(-5, 5, inplace=True)
    df["OI_NWCFA"].clip(-5, 5, inplace=True)
    df["EV_EBIT"].clip(-500, 500, inplace=True)
    df["PE"].clip(-1000, 1000, inplace=True)
    df["PB"].clip(-50, 100, inplace=True)    
    df["PS"].clip(0, 500, inplace=True)
    df["OI_IntExp"].clip(-600, 600, inplace=True)#-600, 600
    df["WorkingCap"].clip(0, 30, inplace=True)  
    df["ROCE"].clip(-2, 2, inplace=True)
    df["DE"].clip(0, 100, inplace=True)
    df["DebtRatio"].clip(0, 50, inplace=True)  
    df["CashRatio"].clip(0, 30, inplace=True)
    df["AssetTurnover"].clip(-2000, 2000, inplace=True)# 0, 500
    df["GPM"].clip(0, 1, inplace=True) #how can be >100%?
    df["WC_TA"].clip(-1.5, 2, inplace=True)
    df["RE_TA"].clip(-20, 2, inplace=True)
    df["EBIT_TA"].clip(-2, 1, inplace=True)
    df["Equity_Liab"].clip(-2, 20, inplace=True)
    df.fillna(0, inplace=True)
    
    return df
# Out:
# time: 0 ns (started: 2022-10-08 09:35:14 +08:00)

# %%
X = getRatios(x)
fixRatios(X)
# Out:
#           EV_EBIT  OI_NWCFA          PE         PB         PS   OI_IntExp  \
# 0       82.797844  0.054971  112.795556   3.347207  12.792295   11.437500
# 1       73.741818  0.064395   93.220476   3.642102  14.677638   12.875000
# 2       85.881068  0.061131  109.984756   4.122857  16.367967   13.400000
# 3       93.118058  0.057908  112.367543   4.264654  17.651993   15.461538
# 4       89.891130  0.063609  125.146780   4.581382  18.629924   17.923077
# ...           ...       ...         ...        ...        ...         ...
# 38302  401.544454  0.027134  455.367693  11.194813  30.310853  281.800000
# 38303  206.724364  0.041892  278.735919   8.760902  19.453274  459.400000
# 38304 -451.177169 -0.020088 -738.189122   9.281098  21.600759 -120.111111
# 38305  133.457796  0.069059  192.831728   9.449764  17.454435   84.777778
# 38306   47.072701  0.130154   67.809883   6.533534  11.904644  447.000000
#
#        WorkingCap       ROE      ROCE        DE  DebtRatio  CashRatio  \
# 0        3.846561  0.029675  0.024383  0.835610   2.196731   2.422222
# 1        3.337925  0.039070  0.030812  0.830698   2.203807   2.057851
# 2        3.201348  0.037486  0.030165  0.832229   2.201593   2.012637
# 3        3.219984  0.037953  0.029345  0.791585   2.263288   2.065270
# 4        3.300871  0.036608  0.033366  0.742709   2.346422   2.120348
# ...           ...       ...       ...       ...        ...        ...
# 38302    7.889376  0.024584  0.024432  0.198130   6.047194   5.651679
# 38303    6.229416  0.031431  0.035773  0.269457   4.711162   3.871998
# 38304    6.530220 -0.012573 -0.017744  0.250797   4.987290   3.589801
# 38305    6.948487  0.049005  0.050998  0.460698   3.170619   3.636261
# 38306    6.787602  0.096351  0.100036  0.431346   3.318325   3.436455
#
#        AssetTurnover       GPM     WC_TA     RE_TA   EBIT_TA  Equity_Liab
# 0           1.738654  0.529253  0.345137  0.781242  0.021427     1.196731
# 1           1.633997  0.537957  0.323425 -0.057546  0.026550     1.203807
# 2           1.632593  0.537205  0.325973 -0.049027  0.025699     1.201593
# 3           1.555866  0.535009  0.333495 -0.031473  0.024936     1.263288
# 4           1.570674  0.544155  0.344885 -0.014954  0.028365     1.346422
# ...              ...       ...       ...       ...       ...          ...
# 38302      11.991617  0.785479  0.773617  0.333149  0.021689     5.047194
# 38303      13.301299  0.778988  0.733024  0.324628  0.030759     3.711162
# 38304      10.494563  0.756041  0.733442  0.323538 -0.015391     3.987290
# 38305      13.172824  0.765747  0.631891  0.305049  0.045581     2.170619
# 38306      15.439858  0.803455  0.656570  0.348743  0.088688     2.318325
#
# [38307 rows x 18 columns]
# time: 47 ms (started: 2022-10-08 09:35:14 +08:00)

# %% [markdown]
# ## Feature engineer y dataframe

# %%
y.tail()
# Out:
#       Ticker      Date1  Open1    Volume1      Date2  Open2   Volume2
# 38302   ZYXI 2020-09-30  15.55  1115434.0 2021-09-30  10.58  252514.0
# 38303   ZYXI 2020-12-31  12.71   318435.0 2021-12-31    NaN       NaN
# 38304   ZYXI 2021-03-31  13.60   423240.0 2022-03-31    NaN       NaN
# 38305   ZYXI 2021-06-30  14.13   144577.0 2022-06-30    NaN       NaN
# 38306   ZYXI 2021-09-30  10.58   252514.0 2022-09-30    NaN       NaN
# time: 0 ns (started: 2022-10-08 09:35:14 +08:00)

# %%
# Create function to calculate the stock performance

def getReturns(df):
    '''
    Takes in df, which has the stock prices and respective dates
    Returns a DataFrame df1 containing the ticker and the 
    relative change in price onldf1 ("Returns").
    '''
    df1=pd.DataFrame()
    df1["Ticker"] = df["Ticker"]
    df1["Returns"] = np.where(df['Open2'].isnull(), None, (df["Open2"]-df["Open1"]) / df["Open1"])
    
    return df1
    
    
#     if df['Open2'].isnull():
#         df1["Returns"] = df['Open2'].isnull()
#     else:
#         df1["Returns"] = (df["Open2"]-df["Open1"]) / df["Open1"]
#     return df1
# Out:
# time: 0 ns (started: 2022-10-08 09:35:14 +08:00)

# %%
y = getReturns(y)
y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38307 entries, 0 to 38306
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ticker   38307 non-null  object
#  1   Returns  29650 non-null  object
# dtypes: object(2)
# memory usage: 598.7+ KB
# time: 15 ms (started: 2022-10-08 09:35:14 +08:00)

# %% [markdown]
# ## REDO THIS VISUALISATION LATER

# %%
# # Make a plot of the distributions.
# cols, rows = 3, 5
# plt.figure(figsize=(5*cols, 5*rows))
# for i in range(1, cols*rows):
#     if i<len(x.keys()):
#         plt.subplot(rows, cols, i)
#         k=x.keys()[i]
#         x[k].hist(bins=100)
#         plt.title(k);
# Out:
# time: 0 ns (started: 2022-10-08 09:35:14 +08:00)

# %%
# See one of the distributions
k=X.keys()[2] # Try different numbers, 0-14.
X[k].hist(bins=100, figsize=(6,5))
plt.title(k);
# Out:
# time: 265 ms (started: 2022-10-08 09:35:15 +08:00)

# %%
# Make a plot of the distributions.
cols, rows = 3, 6
plt.figure(figsize=(5*cols, 5*rows))

for i in range(0, cols*rows):
    if i<len(X.keys()):
        plt.subplot(rows, cols, i+1)
        k=X.keys()[i]
        X[k].hist(bins=100)
        plt.title(k);
# Out:
# time: 3.53 s (started: 2022-10-08 09:35:15 +08:00)

# %%
# save to csv
X.to_csv("./data/03_PerformancePct.csv")
y.to_csv("./data/03_FundamentalRatios.csv")
# Out:
# time: 906 ms (started: 2022-10-08 09:35:18 +08:00)

# %% [markdown]
# Data does not seem to have good distribution. Try using PowerTransformer to get good distributions and to make data more Gaussian-like.
#
# This is useful for modeling issues related to heteroscedasticity (non-constant variance), or other situations where normality is desired.

# %%
from sklearn.preprocessing import PowerTransformer
# Out:
# time: 203 ms (started: 2022-10-08 09:35:19 +08:00)

# %%
# There are a total of 18 features
X.columns
# Out:
# Index(['EV_EBIT', 'OI_NWCFA', 'PE', 'PB', 'PS', 'OI_IntExp', 'WorkingCap',
#        'ROE', 'ROCE', 'DE', 'DebtRatio', 'CashRatio', 'AssetTurnover', 'GPM',
#        'WC_TA', 'RE_TA', 'EBIT_TA', 'Equity_Liab'],
#       dtype='object')
# time: 0 ns (started: 2022-10-08 09:35:19 +08:00)

# %%
# Instantiate the PowerTransformer, then fit and transform the data
transformer = PowerTransformer()
X_transformed = pd.DataFrame(transformer.fit_transform(X), columns=X.columns)

# Define function to plot X features
def plotFeatures(feature_index, df):
    feature = df.columns[feature_index]
    plt.hist(df[feature], density=True, bins=30)
    plt.grid()
    plt.xlabel(feature)
    plt.ylabel('Probability')
# Out:
# time: 563 ms (started: 2022-10-08 09:35:19 +08:00)

# %%
# Visualise some features before and after transformation
plot_list = [4,6,9,10,11] # using indexing

plt.figure(figsize=(13,20))
j=1
for i in plot_list:
    
    # create subplots with number of rows, columns and index (starts with 1)
    plt.subplot(len(plot_list), 2, 2*j-1)
    plotFeatures(i, X)
    if j==1:
        plt.title('Before Transformation',fontsize=17)
    
    plt.subplot(len(plot_list),2,2*j)
    plotFeatures(i, X_transformed)
    if j==1:
        plt.title('After Transformation',fontsize=17)
    j+=1
    
plt.savefig('TransformedFeatures.png', dpi=300)
# Out:
# time: 2.59 s (started: 2022-10-08 09:35:20 +08:00)

# %%
pickle.dump(X, open('./data/fundamentals3.pkl', 'wb'))
pickle.dump(y, open('./data/performance3.pkl', 'wb'))
# Out:
# time: 16 ms (started: 2022-10-08 09:35:23 +08:00)

# %%
# save the final file to csv
X.to_csv("./data/Final_StocksFundamentals.csv")
y.to_csv("./data/Final_StockPerformanceAnnual.csv")
# Out:
# time: 781 ms (started: 2022-10-08 09:35:23 +08:00)

# %%
X.head()
# Out:
#      EV_EBIT  OI_NWCFA          PE        PB         PS  OI_IntExp  \
# 0  82.797844  0.054971  112.795556  3.347207  12.792295  11.437500
# 1  73.741818  0.064395   93.220476  3.642102  14.677638  12.875000
# 2  85.881068  0.061131  109.984756  4.122857  16.367967  13.400000
# 3  93.118058  0.057908  112.367543  4.264654  17.651993  15.461538
# 4  89.891130  0.063609  125.146780  4.581382  18.629924  17.923077
#
#    WorkingCap       ROE      ROCE        DE  DebtRatio  CashRatio  \
# 0    3.846561  0.029675  0.024383  0.835610   2.196731   2.422222
# 1    3.337925  0.039070  0.030812  0.830698   2.203807   2.057851
# 2    3.201348  0.037486  0.030165  0.832229   2.201593   2.012637
# 3    3.219984  0.037953  0.029345  0.791585   2.263288   2.065270
# 4    3.300871  0.036608  0.033366  0.742709   2.346422   2.120348
#
#    AssetTurnover       GPM     WC_TA     RE_TA   EBIT_TA  Equity_Liab
# 0       1.738654  0.529253  0.345137  0.781242  0.021427     1.196731
# 1       1.633997  0.537957  0.323425 -0.057546  0.026550     1.203807
# 2       1.632593  0.537205  0.325973 -0.049027  0.025699     1.201593
# 3       1.555866  0.535009  0.333495 -0.031473  0.024936     1.263288
# 4       1.570674  0.544155  0.344885 -0.014954  0.028365     1.346422
# time: 0 ns (started: 2022-10-08 09:35:23 +08:00)

# %%
y.head()
# Out:
#   Ticker   Returns
# 0      A  0.563351
# 1      A  0.535595
# 2      A  0.198018
# 3      A  0.076426
# 4      A -0.050044
# time: 0 ns (started: 2022-10-08 09:35:23 +08:00)
