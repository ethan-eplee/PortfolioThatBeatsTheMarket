# %%
# %load_ext autotime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import pickle
import warnings
warnings.filterwarnings("ignore")
# Out:
# time: 1.06 s (started: 2022-10-11 21:29:02 +08:00)

# %%
# reopen the pickle file from previous notebook
# recall that x is the fundamentals data and y is the price data
x = pickle.load(open('./data/02_fundamentals.pkl', 'rb'))
y = pickle.load(open('./data/02_pricedata.pkl', 'rb'))
# Out:
# time: 31 ms (started: 2022-10-11 21:29:03 +08:00)

# %%
print(x.shape)
print(y.shape)
# Out:
# (29650, 74)
# (29650, 7)
# time: 0 ns (started: 2022-10-11 21:29:03 +08:00)

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29650 entries, 0 to 29649
# Data columns (total 74 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Ticker                                           29650 non-null  object
#  1   Report Date                                      29650 non-null  datetime64[ns]
#  2   SimFinId                                         29650 non-null  int64
#  3   Currency                                         29650 non-null  object
#  4   Fiscal Year                                      29650 non-null  int64
#  5   Fiscal Period_x                                  29650 non-null  object
#  6   Publish Date                                     29650 non-null  datetime64[ns]
#  7   Restated Date_x                                  29650 non-null  datetime64[ns]
#  8   Shares (Basic)_x                                 29650 non-null  float64
#  9   Shares (Diluted)_x                               29650 non-null  float64
#  10  Revenue                                          28959 non-null  float64
#  11  Cost of Revenue                                  26680 non-null  float64
#  12  Gross Profit                                     26671 non-null  float64
#  13  Operating Expenses                               29605 non-null  float64
#  14  Selling, General & Administrative                28151 non-null  float64
#  15  Research & Development                           12537 non-null  float64
#  16  Depreciation & Amortization_x                    13311 non-null  float64
#  17  Operating Income (Loss)                          29649 non-null  float64
#  18  Non-Operating Income (Loss)                      29506 non-null  float64
#  19  Interest Expense, Net                            26482 non-null  float64
#  20  Pretax Income (Loss), Adj.                       29650 non-null  int64
#  21  Abnormal Gains (Losses)                          17105 non-null  float64
#  22  Pretax Income (Loss)                             29650 non-null  int64
#  23  Income Tax (Expense) Benefit, Net                27063 non-null  float64
#  24  Income (Loss) from Continuing Operations         29650 non-null  int64
#  25  Net Extraordinary Gains (Losses)                 3769 non-null   float64
#  26  Net Income                                       29650 non-null  int64
#  27  Net Income (Common)                              29650 non-null  int64
#  28  Fiscal Period_y                                  29650 non-null  object
#  29  Restated Date_y                                  29650 non-null  datetime64[ns]
#  30  Shares (Basic)_y                                 29650 non-null  float64
#  31  Shares (Diluted)_y                               29650 non-null  float64
#  32  Cash, Cash Equivalents & Short Term Investments  29565 non-null  float64
#  33  Accounts & Notes Receivable                      26962 non-null  float64
#  34  Inventories                                      19784 non-null  float64
#  35  Total Current Assets                             29650 non-null  float64
#  36  Property, Plant & Equipment, Net                 29226 non-null  float64
#  37  Long Term Investments & Receivables              7749 non-null   float64
#  38  Other Long Term Assets                           29420 non-null  float64
#  39  Total Noncurrent Assets                          29615 non-null  float64
#  40  Total Assets                                     29650 non-null  int64
#  41  Payables & Accruals                              29554 non-null  float64
#  42  Short Term Debt                                  18949 non-null  float64
#  43  Total Current Liabilities                        29650 non-null  int64
#  44  Long Term Debt                                   23835 non-null  float64
#  45  Total Noncurrent Liabilities                     29354 non-null  float64
#  46  Total Liabilities                                29650 non-null  int64
#  47  Share Capital & Additional Paid-In Capital       29256 non-null  float64
#  48  Treasury Stock                                   13159 non-null  float64
#  49  Retained Earnings                                28309 non-null  float64
#  50  Total Equity                                     29648 non-null  float64
#  51  Total Liabilities & Equity                       29650 non-null  int64
#  52  Fiscal Period                                    29650 non-null  object
#  53  Restated Date                                    29650 non-null  datetime64[ns]
#  54  Shares (Basic)                                   29650 non-null  float64
#  55  Shares (Diluted)                                 29650 non-null  float64
#  56  Net Income/Starting Line                         29259 non-null  float64
#  57  Depreciation & Amortization_y                    28897 non-null  float64
#  58  Non-Cash Items                                   29282 non-null  float64
#  59  Change in Working Capital                        29077 non-null  float64
#  60  Change in Accounts Receivable                    2214 non-null   float64
#  61  Change in Inventories                            1617 non-null   float64
#  62  Change in Accounts Payable                       1804 non-null   float64
#  63  Change in Other                                  2629 non-null   float64
#  64  Net Cash from Operating Activities               29648 non-null  float64
#  65  Change in Fixed Assets & Intangibles             28988 non-null  float64
#  66  Net Change in Long Term Investment               10745 non-null  float64
#  67  Net Cash from Acquisitions & Divestitures        13775 non-null  float64
#  68  Net Cash from Investing Activities               29501 non-null  float64
#  69  Dividends Paid                                   14362 non-null  float64
#  70  Cash from (Repayment of) Debt                    24815 non-null  float64
#  71  Cash from (Repurchase of) Equity                 24808 non-null  float64
#  72  Net Cash from Financing Activities               29494 non-null  float64
#  73  Net Change in Cash                               29650 non-null  int64
# dtypes: datetime64[ns](5), float64(52), int64(12), object(5)
# memory usage: 16.7+ MB
# time: 15 ms (started: 2022-10-11 21:29:03 +08:00)

# %% [markdown]
# As there are still some null values, we would need to fix these as any feature engineered ratio could give us an error. Let's fill these null values with zero first.

# %%
x = x.fillna(0)
# Out:
# time: 516 ms (started: 2022-10-11 21:29:03 +08:00)

# %%
# total of 29650 rows
y
# Out:
#       Ticker      Date1  Open1    Volume1      Date2  Open2    Volume2
# 0          A 2016-10-31  43.33  1556762.0 2017-10-31  67.74  1609938.0
# 1          A 2017-01-31  48.04  2552612.0 2018-01-31  73.77  1949108.0
# 2          A 2017-04-30  55.50  1897018.0 2018-04-30  66.49  2277705.0
# 3          A 2017-07-31  60.32  1038744.0 2018-07-31  64.93  2539265.0
# 4          A 2017-10-31  67.74  1609938.0 2018-10-31  64.35  3820987.0
# ...      ...        ...    ...        ...        ...    ...        ...
# 29645   ZYXI 2019-09-30   8.65   177336.0 2020-09-29  15.33   382097.0
# 29646   ZYXI 2019-12-31   7.13   129247.0 2020-12-30  12.13   487832.0
# 29647   ZYXI 2020-03-31   9.71   308449.0 2021-03-31  13.60   423240.0
# 29648   ZYXI 2020-06-30  20.95  1160230.0 2021-06-30  14.13   144577.0
# 29649   ZYXI 2020-09-30  15.55  1115434.0 2021-09-30  10.58   252514.0
#
# [29650 rows x 7 columns]
# time: 16 ms (started: 2022-10-11 21:29:03 +08:00)

# %% [markdown]
# ## Add in 3 new columns
# - Market cap: Diluted shares x Open price at that date
# - EV: Market cap + LT Debt + ST Debt - Cash
# - EBIT: Net Income - Interest Expense - Net Income Tax (Expense) Benefit

# %%
# Add in three new columns

x['Market Cap'] = x['Shares (Diluted)_x'] * y['Open1']
x['EV'] = x['Market Cap'] + x['Long Term Debt'] + x['Short Term Debt'] - x['Cash, Cash Equivalents & Short Term Investments']
x['EBIT'] = x['Net Income'] - x['Interest Expense, Net'] - x['Income Tax (Expense) Benefit, Net']
# Out:
# time: 0 ns (started: 2022-10-11 21:29:03 +08:00)

# %%
x.head()
# Out:
#   Ticker Report Date  SimFinId Currency  Fiscal Year Fiscal Period_x  \
# 0      A  2016-10-31     45846      USD         2016              Q4
# 1      A  2017-01-31     45846      USD         2017              Q1
# 2      A  2017-04-30     45846      USD         2017              Q2
# 3      A  2017-07-31     45846      USD         2017              Q3
# 4      A  2017-10-31     45846      USD         2017              Q4
#
#   Publish Date Restated Date_x  Shares (Basic)_x  Shares (Diluted)_x  ...  \
# 0   2016-12-20      2018-12-20       324000000.0         328000000.0  ...
# 1   2017-03-08      2018-03-06       322000000.0         326000000.0  ...
# 2   2017-06-06      2018-05-31       321000000.0         325000000.0  ...
# 3   2017-09-06      2018-08-30       321000000.0         326000000.0  ...
# 4   2017-12-21      2018-12-20       324000000.0         327000000.0  ...
#
#    Net Cash from Acquisitions & Divestitures  \
# 0                                -26000000.0
# 1                                -69000000.0
# 2                                        0.0
# 3                                -57000000.0
# 4                                        0.0
#
#    Net Cash from Investing Activities  Dividends Paid  \
# 0                         -78000000.0     -38000000.0
# 1                        -101000000.0     -42000000.0
# 2                         -43000000.0     -43000000.0
# 3                        -101000000.0     -42000000.0
# 4                         -60000000.0     -43000000.0
#
#    Cash from (Repayment of) Debt  Cash from (Repurchase of) Equity  \
# 0                     27000000.0                       -43000000.0
# 1                     89000000.0                       -93000000.0
# 2                     52000000.0                       -75000000.0
# 3                     39000000.0                        32000000.0
# 4                    -70000000.0                         8000000.0
#
#    Net Cash from Financing Activities  Net Change in Cash    Market Cap  \
# 0                         -56000000.0            90000000  1.421224e+10
# 1                         -58000000.0           -48000000  1.566104e+10
# 2                         -67000000.0           148000000  1.803750e+10
# 3                          29000000.0           174000000  1.966432e+10
# 4                        -106000000.0           115000000  2.215098e+10
#
#              EV         EBIT
# 0  1.382724e+10  167000000.0
# 1  1.541204e+10  209000000.0
# 2  1.769150e+10  206000000.0
# 3  1.918232e+10  206000000.0
# 4  2.148398e+10  239000000.0
#
# [5 rows x 77 columns]
# time: 31 ms (started: 2022-10-11 21:29:03 +08:00)

# %% [markdown]
# ## Define function to develop financial ratios

# %%
# Create a function to feature engineer many different financial ratios
# Takes in original fundamental dataframe then output all the ratio

def getRatios(df):    
    # Create a new dataframe to copy ratios into
    df1 = pd.DataFrame()
    
    # EV/EBIT
    df1['EV_EBIT'] = df['EV']/df['EBIT']

    # Operating Income over (Net working capital + Fidfed assets)
    df1['OI_NWCFA'] = df['Operating Income (Loss)']/\
    (df['Total Current Assets'] - df['Total Current Liabilities'] + df['Property, Plant & Equipment, Net'])

    # Price to earnings
    df1['PE'] = df['Market Cap']/df['Net Income']

    # Price to book
    df1['PB'] = df['Market Cap']/df['Total Equity']

    # Price to sales
    df1['PS'] = df['Market Cap']/df['Revenue']

    # Operating Income over Interest Edfpense
    df1['OI_IntExp'] = df['Operating Income (Loss)']/ -df['Interest Expense, Net']

    # Working Capital Ratio (CA/CL)
    df1['WorkingCap'] = df['Total Current Assets']/ df['Total Current Liabilities']

    # Return on Equity
    df1['ROE'] = df['Net Income']/ df['Total Equity']

    # Return on Capital Employed
    df1['ROCE'] = df['EBIT']/ (df['Total Assets'] - df['Total Current Liabilities'])

    # Debt/Equity
    df1['DE'] = df['Total Liabilities']/ df['Total Equity']

    # Debt Ratio
    df1['DebtRatio'] = df['Total Assets']/ df['Total Liabilities']

    # Cash Ratio
    df1['CashRatio'] = df['Cash, Cash Equivalents & Short Term Investments']/ df['Total Current Liabilities']

    # Asset Turnover
    df1['AssetTurnover'] = df['Revenue']/ df['Property, Plant & Equipment, Net']

    # Gross Profit Margin
    df1['GPM'] = df['Gross Profit']/ df['Revenue']

    # Working Capital over total assets
    df1['WC_TA'] = (df['Total Current Assets'] - df['Total Current Liabilities'])/ df['Total Assets']

    # Retained earnings over total assets
    df1['RE_TA'] = df['Retained Earnings']/ df['Total Assets']

    # EBIT over total assets
    df1['EBIT_TA'] = df['EBIT']/ df['Total Assets']

    # Equity over liabilities
    df1['Equity_Liab'] = df['Total Equity']/ df['Total Liabilities']
    
    return df1
# Out:
# time: 0 ns (started: 2022-10-11 21:29:03 +08:00)

# %%
def fixRatios(df):
    '''
    Takes in original df, edits it to have the distributions clipped.
    The distribution clippings are done manually by eye, with human judgement based on the information.
    '''
    df["ROE"].clip(-5, 5, inplace=True)
    df["OI_NWCFA"].clip(-5, 5, inplace=True)
    df["EV_EBIT"].clip(-500, 500, inplace=True)
    df["PE"].clip(-1000, 1000, inplace=True)
    df["PB"].clip(-50, 100, inplace=True)    
    df["PS"].clip(0, 500, inplace=True)
    df["OI_IntExp"].clip(-600, 600, inplace=True) #-600, 600
    df["WorkingCap"].clip(0, 30, inplace=True)  
    df["ROCE"].clip(-2, 2, inplace=True)
    df["DE"].clip(0, 100, inplace=True)
    df["DebtRatio"].clip(0, 50, inplace=True)  
    df["CashRatio"].clip(0, 30, inplace=True)
    df["AssetTurnover"].clip(-2000, 2000, inplace=True) # 0, 500
    df["GPM"].clip(0, 1, inplace=True)
    df["WC_TA"].clip(-1.5, 2, inplace=True)
    df["RE_TA"].clip(-20, 2, inplace=True)
    df["EBIT_TA"].clip(-2, 1, inplace=True)
    df["Equity_Liab"].clip(-2, 20, inplace=True)
    df.fillna(0, inplace=True)
    
    return df
# Out:
# time: 0 ns (started: 2022-10-11 21:29:03 +08:00)

# %%
X = getRatios(x)
fixRatios(X)
# Out:
#           EV_EBIT  OI_NWCFA          PE         PB         PS   OI_IntExp  \
# 0       82.797844  0.054971  112.795556   3.347207  12.792295   11.437500
# 1       73.741818  0.064395   93.220476   3.642102  14.677638   12.875000
# 2       85.881068  0.061131  109.984756   4.122857  16.367967   13.400000
# 3       93.118058  0.057908  112.367543   4.264654  17.651993   15.461538
# 4       89.891130  0.063609  125.146780   4.581382  18.629924   17.923077
# ...           ...       ...         ...        ...        ...         ...
# 29645  125.173810  0.167461  159.489747  19.780543  27.438661 -600.000000
# 29646   67.921239  0.204696   90.754714  13.608820  18.885337  600.000000
# 29647  142.696470  0.117159  124.389828  15.674143  23.990867  600.000000
# 29648  190.226788  0.162071  263.172831  29.454035  41.218524  600.000000
# 29649  401.544454  0.027134  455.367693  11.194813  30.310853  281.800000
#
#        WorkingCap       ROE      ROCE        DE  DebtRatio  CashRatio  \
# 0        3.846561  0.029675  0.024383  0.835610   2.196731   2.422222
# 1        3.337925  0.039070  0.030812  0.830698   2.203807   2.057851
# 2        3.201348  0.037486  0.030165  0.832229   2.201593   2.012637
# 3        3.219984  0.037953  0.029345  0.791585   2.263288   2.065270
# 4        3.300871  0.036608  0.033366  0.742709   2.346422   2.120348
# ...           ...       ...       ...       ...        ...        ...
# 29645    4.124364  0.124024  0.123484  0.508297   2.967355   2.640850
# 29646    4.342120  0.149952  0.161655  0.438813   3.278873   2.701559
# 29647    4.404868  0.126008  0.089747  0.425348   3.351019   2.500000
# 29648    4.955648  0.111919  0.132893  0.363616   3.750153   2.809967
# 29649    7.889376  0.024584  0.024432  0.198130   6.047194   5.651679
#
#        AssetTurnover       GPM     WC_TA     RE_TA   EBIT_TA  Equity_Liab
# 0           1.738654  0.529253  0.345137  0.781242  0.021427     1.196731
# 1           1.633997  0.537957  0.323425 -0.057546  0.026550     1.203807
# 2           1.632593  0.537205  0.325973 -0.049027  0.025699     1.201593
# 3           1.555866  0.535009  0.333495 -0.031473  0.024936     1.263288
# 4           1.570674  0.544155  0.344885 -0.014954  0.028365     1.346422
# ...              ...       ...       ...       ...       ...          ...
# 29645      15.150000  0.808665  0.571065  0.461454  0.100914     1.967355
# 29646      16.505828  0.800805  0.614245  0.507692  0.131945     2.278873
# 29647      13.645161  0.776661  0.597917  0.520529  0.073987     2.351019
# 29648      13.838362  0.789181  0.647814  0.552518  0.111129     2.750153
# 29649      11.991617  0.785479  0.773617  0.333149  0.021689     5.047194
#
# [29650 rows x 18 columns]
# time: 47 ms (started: 2022-10-11 21:29:03 +08:00)

# %% [markdown]
# ## Feature engineer y dataframe

# %%
# Create function to calculate the stock performance

def getReturns(df):
    '''
    Takes in df, which has the stock prices and respective dates
    Returns a DataFrame df1 containing the ticker and the relative change in price
    '''
    df1=pd.DataFrame()
    df1["Ticker"] = df["Ticker"]
    df1["Returns"] = np.where(df['Open2'].isnull(), None, (df["Open2"]-df["Open1"]) / df["Open1"])
    
    return df1
# Out:
# time: 0 ns (started: 2022-10-11 21:29:03 +08:00)

# %%
y = getReturns(y)
y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29650 entries, 0 to 29649
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ticker   29650 non-null  object
#  1   Returns  29650 non-null  object
# dtypes: object(2)
# memory usage: 463.4+ KB
# time: 0 ns (started: 2022-10-11 21:29:03 +08:00)

# %% [markdown]
# ## Visualisation of the ratios distribution

# %%
# Visualise one of the distribution, in this case the P/E ratio
# Try different numbers 0-17 since we have 18 different ratios
k = X.keys()[2]
X[k].hist(bins=100, figsize=(6,5))
plt.title(k);
# Out:
# time: 188 ms (started: 2022-10-11 21:29:03 +08:00)

# %%
# Make a 3x6 plot of all of the ratio distributions
cols, rows = 3, 6
plt.figure(figsize=(5*cols, 5*rows))

# plot for 18 ratios
for i in range(0, cols*rows):
    plt.subplot(rows, cols, i+1)
    k = X.keys()[i]
    X[k].hist(bins=100)
    plt.title(k);
# Out:
# time: 3 s (started: 2022-10-11 21:29:04 +08:00)

# %% [markdown]
# Data does not seem to have good distribution. Try using PowerTransformer to get good distributions and to make data more Gaussian-like.
#
# This is useful for modeling issues related to heteroscedasticity (non-constant variance), or other situations where normality is desired.

# %%
from sklearn.preprocessing import PowerTransformer
# Out:
# time: 203 ms (started: 2022-10-11 21:29:07 +08:00)

# %%
# There are a total of 18 features
X.columns
# Out:
# Index(['EV_EBIT', 'OI_NWCFA', 'PE', 'PB', 'PS', 'OI_IntExp', 'WorkingCap',
#        'ROE', 'ROCE', 'DE', 'DebtRatio', 'CashRatio', 'AssetTurnover', 'GPM',
#        'WC_TA', 'RE_TA', 'EBIT_TA', 'Equity_Liab'],
#       dtype='object')
# time: 0 ns (started: 2022-10-11 21:29:07 +08:00)

# %%
# Instantiate the PowerTransformer, then fit and transform the data
transformer = PowerTransformer()
X_transformed = pd.DataFrame(transformer.fit_transform(X), columns=X.columns)
# Out:
# time: 421 ms (started: 2022-10-11 21:29:07 +08:00)

# %%
# Ratios have been transformed to have a more Gaussian-like distribution
X_transformed
# Out:
#         EV_EBIT  OI_NWCFA        PE        PB        PS  OI_IntExp  \
# 0      0.189940  0.043193  0.221184 -0.059364  0.358464   0.039461
# 1      0.124845  0.061792  0.136453 -0.034656  0.457170   0.046534
# 2      0.212166  0.055351  0.208997  0.005473  0.533831   0.049123
# 3      0.264452  0.048989  0.219328  0.017275  0.586095   0.059316
# 4      0.241118  0.060241  0.274815  0.043585  0.622978   0.071540
# ...         ...       ...       ...       ...       ...        ...
# 29645  0.497778  0.265299  0.424510  1.259499  0.876994  -2.315824
# 29646  0.083165  0.338858  0.125806  0.773705  0.632234   3.211759
# 29647  0.626335  0.165958  0.271525  0.937158  0.791068   3.211759
# 29648  0.977923  0.254653  0.880267  2.008181  1.123263   3.211759
# 29649  2.574800 -0.011743  1.734861  0.581295  0.939202   1.465374
#
#        WorkingCap       ROE      ROCE        DE  DebtRatio  CashRatio  \
# 0        0.904214  0.072196  0.143592 -0.269526   0.299047   1.224378
# 1        0.735592  0.091093  0.180702 -0.275029   0.304858   1.105696
# 2        0.684993  0.087907  0.176966 -0.273311   0.303042   1.088813
# 3        0.692046  0.088846  0.172226 -0.319730   0.352650   1.108415
# 4        0.722111  0.086141  0.195454 -0.377918   0.416472   1.128170
# ...           ...       ...       ...       ...        ...        ...
# 29645    0.985168  0.262269  0.720621 -0.699637   0.805105   1.283419
# 29646    1.044011  0.314614  0.945645 -0.811466   0.955827   1.298489
# 29647    1.060281  0.266274  0.522998 -0.834180   0.987517   1.246290
# 29648    1.191512  0.237847  0.775949 -0.943040   1.144686   1.324119
# 29649    1.664643  0.061959  0.143874 -1.279934   1.691397   1.683713
#
#        AssetTurnover       GPM     WC_TA     RE_TA   EBIT_TA  Equity_Liab
# 0          -0.086774  0.553581  0.487407  1.472865  0.240327     0.271010
# 1          -0.087656  0.584363  0.409550 -0.165967  0.300780     0.276344
# 2          -0.087668  0.581709  0.418680 -0.155501  0.290706     0.274678
# 3          -0.088318  0.573953  0.445640 -0.133590  0.281695     0.320236
# 4          -0.088192  0.606200  0.486501 -0.112533  0.322300     0.378920
# ...              ...       ...       ...       ...       ...          ...
# 29645       0.008100  1.480863  1.306058  0.696901  1.228153     0.740164
# 29646       0.016716  1.456341  1.464191  0.797155  1.643138     0.883434
# 29647      -0.001596  1.380503  1.404336  0.825694  0.881502     0.913890
# 29648      -0.000343  1.419928  1.587476  0.898152  1.362923     1.067056
# 29649      -0.012428  1.408291  2.052113  0.439288  0.243406     1.643408
#
# [29650 rows x 18 columns]
# time: 31 ms (started: 2022-10-11 21:29:07 +08:00)

# %%
# Define function to plot distribution of the transformed ratios
def plotFeatures(ratio_index, df):
    ratio = df.columns[ratio_index]
    plt.hist(df[ratio], density=True, bins=30)
    plt.grid()
    plt.xlabel(ratio, fontsize=12)
    plt.ylabel('Frequency', fontsize=12)
# Out:
# time: 0 ns (started: 2022-10-11 21:29:07 +08:00)

# %%
# Visualise some features before and after transformation using indexing
plot_list = [2,4,6,9,10,11]

plt.figure(figsize=(13,20))
j=1

for i in plot_list:    
    # create subplots with number of rows, columns and index (starts with 1)
    plt.subplot(len(plot_list), 2, 2*j-1)
    plotFeatures(i, X)
    if j==1:
        plt.title('Before Transformation',fontsize=17)
    
    plt.subplot(len(plot_list), 2, 2*j)
    plotFeatures(i, X_transformed)
    if j==1:
        plt.title('After Transformation',fontsize=17)
    j+=1
    
plt.savefig('TransformedFeatures.png', dpi=300)
# Out:
# time: 2.75 s (started: 2022-10-11 21:29:07 +08:00)

# %% [markdown]
# # Save files to csv

# %%
# X has not been power-transformed yet and will be done in the next step
X
# Out:
#           EV_EBIT  OI_NWCFA          PE         PB         PS   OI_IntExp  \
# 0       82.797844  0.054971  112.795556   3.347207  12.792295   11.437500
# 1       73.741818  0.064395   93.220476   3.642102  14.677638   12.875000
# 2       85.881068  0.061131  109.984756   4.122857  16.367967   13.400000
# 3       93.118058  0.057908  112.367543   4.264654  17.651993   15.461538
# 4       89.891130  0.063609  125.146780   4.581382  18.629924   17.923077
# ...           ...       ...         ...        ...        ...         ...
# 29645  125.173810  0.167461  159.489747  19.780543  27.438661 -600.000000
# 29646   67.921239  0.204696   90.754714  13.608820  18.885337  600.000000
# 29647  142.696470  0.117159  124.389828  15.674143  23.990867  600.000000
# 29648  190.226788  0.162071  263.172831  29.454035  41.218524  600.000000
# 29649  401.544454  0.027134  455.367693  11.194813  30.310853  281.800000
#
#        WorkingCap       ROE      ROCE        DE  DebtRatio  CashRatio  \
# 0        3.846561  0.029675  0.024383  0.835610   2.196731   2.422222
# 1        3.337925  0.039070  0.030812  0.830698   2.203807   2.057851
# 2        3.201348  0.037486  0.030165  0.832229   2.201593   2.012637
# 3        3.219984  0.037953  0.029345  0.791585   2.263288   2.065270
# 4        3.300871  0.036608  0.033366  0.742709   2.346422   2.120348
# ...           ...       ...       ...       ...        ...        ...
# 29645    4.124364  0.124024  0.123484  0.508297   2.967355   2.640850
# 29646    4.342120  0.149952  0.161655  0.438813   3.278873   2.701559
# 29647    4.404868  0.126008  0.089747  0.425348   3.351019   2.500000
# 29648    4.955648  0.111919  0.132893  0.363616   3.750153   2.809967
# 29649    7.889376  0.024584  0.024432  0.198130   6.047194   5.651679
#
#        AssetTurnover       GPM     WC_TA     RE_TA   EBIT_TA  Equity_Liab
# 0           1.738654  0.529253  0.345137  0.781242  0.021427     1.196731
# 1           1.633997  0.537957  0.323425 -0.057546  0.026550     1.203807
# 2           1.632593  0.537205  0.325973 -0.049027  0.025699     1.201593
# 3           1.555866  0.535009  0.333495 -0.031473  0.024936     1.263288
# 4           1.570674  0.544155  0.344885 -0.014954  0.028365     1.346422
# ...              ...       ...       ...       ...       ...          ...
# 29645      15.150000  0.808665  0.571065  0.461454  0.100914     1.967355
# 29646      16.505828  0.800805  0.614245  0.507692  0.131945     2.278873
# 29647      13.645161  0.776661  0.597917  0.520529  0.073987     2.351019
# 29648      13.838362  0.789181  0.647814  0.552518  0.111129     2.750153
# 29649      11.991617  0.785479  0.773617  0.333149  0.021689     5.047194
#
# [29650 rows x 18 columns]
# time: 15 ms (started: 2022-10-11 21:29:10 +08:00)

# %%
# Just a dataframe of the tickers and the returns, without dates. Row indexing corresponds to X.
y
# Out:
#       Ticker   Returns
# 0          A  0.563351
# 1          A  0.535595
# 2          A  0.198018
# 3          A  0.076426
# 4          A -0.050044
# ...      ...       ...
# 29645   ZYXI  0.772254
# 29646   ZYXI  0.701262
# 29647   ZYXI  0.400618
# 29648   ZYXI -0.325537
# 29649   ZYXI -0.319614
#
# [29650 rows x 2 columns]
# time: 15 ms (started: 2022-10-11 21:29:10 +08:00)

# %%
pickle.dump(X, open('./data/03_finratios.pkl', 'wb'))
pickle.dump(y, open('./data/03_returns.pkl', 'wb'))
# Out:
# time: 16 ms (started: 2022-10-11 21:29:10 +08:00)

# %%
# save the final file to csv
X.to_csv("./data/03_finratios.csv")
y.to_csv("./data/03_returns.csv")
# Out:
# time: 609 ms (started: 2022-10-11 21:29:10 +08:00)
