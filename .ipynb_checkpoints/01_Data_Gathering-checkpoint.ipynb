# %% [markdown]
# ### Main goal & Problem statement
#
# The project will be building a stock picker with a one year time horizon that utilizes fundamental data from the companies' financial statements for selection.
#
# The main goal would be to pick a portfolio of ten stocks that is able to outperform the market benchmark (S&P500). Regression analysis techniques will be used to determine the return predictions based on the ratios derived from the fundamental information.
#
# A big bulk of the work will be spent on feature engineering of the fundamental data (e.g. financial and accounting ratios), so that these features will correlate with business success and be good performance indicators. Working with time series is also important as we are interested in the performance of the stock when compared to its financial performance.

# %% [markdown]
# ### Proposed methods and models
#
# I will work with models learnt throughout the course that show predictive ability on stock performance, and use them again for backtesting. We can use linear regression, regularized regression (Lasso or Ridge or ENet), KNN, SVM Regressor, Decision Trees as potential models. MSE will likely be the metric to assess the model performance.
#
#
# Feature importance is also something to look at as we want to know which variables/ratios gives us better predictive ability for stock performance. After running these models, we can put them in a table to view the results of the top 10 selected stock portfolios.
#
# After this, we will do backtesting to find out the volatility as well as the return profile of each portfolio. Backtesting will follow roughly these steps:
# - split into train test sets and train model on training set
# - for given year, use model to predict stock returns and pick 10 top performances from test set to create equal weighted portfolio
# - record daily/weekly portfolio value change to see performance of portfolio
# - repeat for the number of years of available data, likely using loops? (we should get return and volatility from here)
#
# From all the models, we should get some kind of return/volatility profile, which we can then use to determine the better stocks to pick.

# %% [markdown]
# ### Relevance
#
# Potentially, this can be used by portfolio managers or retail investors who wish to do better than market returns without taking on too much additional risk. As I do not have any idea how the tested models would do at this point in time, I generally hope that results would at least meet the benchmark return at its minimum. The number of stocks picked is also kept small to minimize potential transaction costs.

# %% [markdown]
# ### Timeline
#
# I will start working on the project right after the completion of Project 4 and aim to come up with a working prototype by the 2nd week of capstone project start. I will try to refine the model in the third week and do up the presentation in the 4th week.

# %% [markdown]
# ## Project starts here

# %%
# %load_ext autotime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import pickle

# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")
# Out:
# time: 1.17 s (started: 2022-10-11 23:28:44 +08:00)

# %% [markdown]
# Simfin is where we will be downloading our fundamentals data from. Instead of downloading a CSV file, we will use the API key to download directly.

# %%
import simfin as sf

# Set your SimFin + API-key for downloading data.
sf.set_api_key('nYdjeL237mt7QaQ4OZTaPa4Xn3YECrTH')

# Set the local directory where data-files are stored.
# The directory will be created if it does not already exist.
sf.set_data_dir('~/simfin_data/')

# Download the data from the SimFin server and load into a Pandas DataFrame.
# We will be getting 3 sets of financial statements (income statement, balance sheet, cashflow statement)
df_income = sf.load_income(variant='quarterly', market='us')
df_balance = sf.load_balance(variant='quarterly', market='us')
df_cashflow = sf.load_cashflow(variant='quarterly', market='us')

# Print the first rows of the data.
df_income.head()
# Out:
# Dataset "us-income-quarterly" on disk (3 days old).
# - Loading from disk ... Done!
# Dataset "us-balance-quarterly" on disk (3 days old).
# - Loading from disk ... Done!
# Dataset "us-cashflow-quarterly" on disk (3 days old).
# - Loading from disk ... Done!
#                     SimFinId Currency  Fiscal Year Fiscal Period Publish Date  \
# Ticker Report Date
# A      2016-10-31      45846      USD         2016            Q4   2016-12-20
#        2017-01-31      45846      USD         2017            Q1   2017-03-08
#        2017-04-30      45846      USD         2017            Q2   2017-06-06
#        2017-07-31      45846      USD         2017            Q3   2017-09-06
#        2017-10-31      45846      USD         2017            Q4   2017-12-21
#
#                    Restated Date  Shares (Basic)  Shares (Diluted)  \
# Ticker Report Date
# A      2016-10-31     2018-12-20     324000000.0       328000000.0
#        2017-01-31     2018-03-06     322000000.0       326000000.0
#        2017-04-30     2018-05-31     321000000.0       325000000.0
#        2017-07-31     2018-08-30     321000000.0       326000000.0
#        2017-10-31     2018-12-20     324000000.0       327000000.0
#
#                          Revenue  Cost of Revenue  ...  \
# Ticker Report Date                                 ...
# A      2016-10-31   1.111000e+09     -523000000.0  ...
#        2017-01-31   1.067000e+09     -493000000.0  ...
#        2017-04-30   1.102000e+09     -510000000.0  ...
#        2017-07-31   1.114000e+09     -518000000.0  ...
#        2017-10-31   1.189000e+09     -542000000.0  ...
#
#                     Non-Operating Income (Loss)  Interest Expense, Net  \
# Ticker Report Date
# A      2016-10-31                   -32000000.0            -16000000.0
#        2017-01-31                   -13000000.0            -16000000.0
#        2017-04-30                   -10000000.0            -15000000.0
#        2017-07-31                    -8000000.0            -13000000.0
#        2017-10-31                    -7000000.0            -13000000.0
#
#                     Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  \
# Ticker Report Date
# A      2016-10-31                    151000000                      NaN
#        2017-01-31                    193000000                      NaN
#        2017-04-30                    191000000                      NaN
#        2017-07-31                    193000000                      NaN
#        2017-10-31                    226000000                      NaN
#
#                     Pretax Income (Loss)  Income Tax (Expense) Benefit, Net  \
# Ticker Report Date
# A      2016-10-31              151000000                        -25000000.0
#        2017-01-31              193000000                        -25000000.0
#        2017-04-30              191000000                        -27000000.0
#        2017-07-31              193000000                        -18000000.0
#        2017-10-31              226000000                        -49000000.0
#
#                     Income (Loss) from Continuing Operations  \
# Ticker Report Date
# A      2016-10-31                                  126000000
#        2017-01-31                                  168000000
#        2017-04-30                                  164000000
#        2017-07-31                                  175000000
#        2017-10-31                                  177000000
#
#                     Net Extraordinary Gains (Losses)  Net Income  \
# Ticker Report Date
# A      2016-10-31                                NaN   126000000
#        2017-01-31                                NaN   168000000
#        2017-04-30                                NaN   164000000
#        2017-07-31                                NaN   175000000
#        2017-10-31                                NaN   177000000
#
#                     Net Income (Common)
# Ticker Report Date
# A      2016-10-31             126000000
#        2017-01-31             168000000
#        2017-04-30             164000000
#        2017-07-31             175000000
#        2017-10-31             177000000
#
# [5 rows x 26 columns]
# time: 1.33 s (started: 2022-10-11 23:28:46 +08:00)

# %%
df_balance.head()
# Out:
#                     SimFinId Currency  Fiscal Year Fiscal Period Publish Date  \
# Ticker Report Date
# A      2016-10-31      45846      USD         2016            Q4   2016-12-20
#        2017-01-31      45846      USD         2017            Q1   2017-03-08
#        2017-04-30      45846      USD         2017            Q2   2017-06-06
#        2017-07-31      45846      USD         2017            Q3   2017-09-06
#        2017-10-31      45846      USD         2017            Q4   2017-12-21
#
#                    Restated Date  Shares (Basic)  Shares (Diluted)  \
# Ticker Report Date
# A      2016-10-31     2017-12-21     324000000.0       328000000.0
#        2017-01-31     2017-03-08     322000000.0       326000000.0
#        2017-04-30     2017-06-06     321000000.0       325000000.0
#        2017-07-31     2017-09-06     321000000.0       326000000.0
#        2017-10-31     2018-12-20     324000000.0       327000000.0
#
#                     Cash, Cash Equivalents & Short Term Investments  \
# Ticker Report Date
# A      2016-10-31                                      2.289000e+09
#        2017-01-31                                      2.241000e+09
#        2017-04-30                                      2.389000e+09
#        2017-07-31                                      2.563000e+09
#        2017-10-31                                      2.678000e+09
#
#                     Accounts & Notes Receivable  ...  Short Term Debt  \
# Ticker Report Date                               ...
# A      2016-10-31                   631000000.0  ...              0.0
#        2017-01-31                   653000000.0  ...      190000000.0
#        2017-04-30                   677000000.0  ...      241000000.0
#        2017-07-31                   678000000.0  ...      280000000.0
#        2017-10-31                   724000000.0  ...      210000000.0
#
#                     Total Current Liabilities  Long Term Debt  \
# Ticker Report Date
# A      2016-10-31                   945000000    1.904000e+09
#        2017-01-31                  1089000000    1.802000e+09
#        2017-04-30                  1187000000    1.802000e+09
#        2017-07-31                  1241000000    1.801000e+09
#        2017-10-31                  1263000000    1.801000e+09
#
#                     Total Noncurrent Liabilities  Total Liabilities  \
# Ticker Report Date
# A      2016-10-31                   2.603000e+09         3548000000
#        2017-01-31                   2.483000e+09         3572000000
#        2017-04-30                   2.454000e+09         3641000000
#        2017-07-31                   2.409000e+09         3650000000
#        2017-10-31                   2.328000e+09         3591000000
#
#                     Share Capital & Additional Paid-In Capital  \
# Ticker Report Date
# A      2016-10-31                                 9.165000e+09
#        2017-01-31                                 5.239000e+09
#        2017-04-30                                 5.242000e+09
#        2017-07-31                                 5.285000e+09
#        2017-10-31                                 5.303000e+09
#
#                     Treasury Stock  Retained Earnings  Total Equity  \
# Ticker Report Date
# A      2016-10-31    -1.050800e+10       6.089000e+09  4.246000e+09
#        2017-01-31     0.000000e+00      -4.530000e+08  4.300000e+09
#        2017-04-30     0.000000e+00      -3.930000e+08  4.375000e+09
#        2017-07-31     0.000000e+00      -2.600000e+08  4.611000e+09
#        2017-10-31              NaN      -1.260000e+08  4.835000e+09
#
#                     Total Liabilities & Equity
# Ticker Report Date
# A      2016-10-31                   7794000000
#        2017-01-31                   7872000000
#        2017-04-30                   8016000000
#        2017-07-31                   8261000000
#        2017-10-31                   8426000000
#
# [5 rows x 28 columns]
# time: 16 ms (started: 2022-10-11 23:28:47 +08:00)

# %%
df_cashflow.head()
# Out:
#                     SimFinId Currency  Fiscal Year Fiscal Period Publish Date  \
# Ticker Report Date
# A      2016-10-31      45846      USD         2016            Q4   2016-12-20
#        2017-01-31      45846      USD         2017            Q1   2017-03-08
#        2017-04-30      45846      USD         2017            Q2   2017-06-06
#        2017-07-31      45846      USD         2017            Q3   2017-09-06
#        2017-10-31      45846      USD         2017            Q4   2017-12-21
#
#                    Restated Date  Shares (Basic)  Shares (Diluted)  \
# Ticker Report Date
# A      2016-10-31     2018-12-20     324000000.0       328000000.0
#        2017-01-31     2018-03-06     322000000.0       326000000.0
#        2017-04-30     2018-05-31     321000000.0       325000000.0
#        2017-07-31     2018-08-30     321000000.0       326000000.0
#        2017-10-31     2018-12-20     324000000.0       327000000.0
#
#                     Net Income/Starting Line  Depreciation & Amortization  \
# Ticker Report Date
# A      2016-10-31                126000000.0                   56000000.0
#        2017-01-31                168000000.0                   55000000.0
#        2017-04-30                164000000.0                   54000000.0
#        2017-07-31                175000000.0                   51000000.0
#        2017-10-31                177000000.0                   52000000.0
#
#                     ...  Net Cash from Operating Activities  \
# Ticker Report Date  ...
# A      2016-10-31   ...                         234000000.0
#        2017-01-31   ...                         116000000.0
#        2017-04-30   ...                         257000000.0
#        2017-07-31   ...                         228000000.0
#        2017-10-31   ...                         288000000.0
#
#                     Change in Fixed Assets & Intangibles  \
# Ticker Report Date
# A      2016-10-31                            -52000000.0
#        2017-01-31                            -32000000.0
#        2017-04-30                            -43000000.0
#        2017-07-31                            -43000000.0
#        2017-10-31                            -58000000.0
#
#                     Net Change in Long Term Investment  \
# Ticker Report Date
# A      2016-10-31                                  0.0
#        2017-01-31                                  NaN
#        2017-04-30                                  NaN
#        2017-07-31                                  NaN
#        2017-10-31                                  0.0
#
#                     Net Cash from Acquisitions & Divestitures  \
# Ticker Report Date
# A      2016-10-31                                 -26000000.0
#        2017-01-31                                 -69000000.0
#        2017-04-30                                         0.0
#        2017-07-31                                 -57000000.0
#        2017-10-31                                         0.0
#
#                     Net Cash from Investing Activities  Dividends Paid  \
# Ticker Report Date
# A      2016-10-31                          -78000000.0     -38000000.0
#        2017-01-31                         -101000000.0     -42000000.0
#        2017-04-30                          -43000000.0     -43000000.0
#        2017-07-31                         -101000000.0     -42000000.0
#        2017-10-31                          -60000000.0     -43000000.0
#
#                     Cash from (Repayment of) Debt  \
# Ticker Report Date
# A      2016-10-31                      27000000.0
#        2017-01-31                      89000000.0
#        2017-04-30                      52000000.0
#        2017-07-31                      39000000.0
#        2017-10-31                     -70000000.0
#
#                     Cash from (Repurchase of) Equity  \
# Ticker Report Date
# A      2016-10-31                        -43000000.0
#        2017-01-31                        -93000000.0
#        2017-04-30                        -75000000.0
#        2017-07-31                         32000000.0
#        2017-10-31                          8000000.0
#
#                     Net Cash from Financing Activities  Net Change in Cash
# Ticker Report Date
# A      2016-10-31                          -56000000.0            90000000
#        2017-01-31                          -58000000.0           -48000000
#        2017-04-30                          -67000000.0           148000000
#        2017-07-31                           29000000.0           174000000
#        2017-10-31                         -106000000.0           115000000
#
# [5 rows x 26 columns]
# time: 16 ms (started: 2022-10-11 23:28:47 +08:00)

# %%
print('Income Statement CSV data is: ', df_income.shape)
print('Balance Sheet CSV data is: ', df_balance.shape)
print('Cash Flow CSV data is: ', df_cashflow.shape)
# Out:
# Income Statement CSV data is:  (41032, 26)
# Balance Sheet CSV data is:  (41032, 28)
# Cash Flow CSV data is:  (41032, 26)
# time: 0 ns (started: 2022-10-11 23:28:47 +08:00)

# %% [markdown]
# Number of rows of data is consistent. There are altogether 36685 rows to use.

# %%
# Merge the data together
# Define the column features where merge takes place
list_to_merge_on = ['Ticker', 'SimFinId', 'Currency', 'Fiscal Year', 'Report Date', 'Publish Date']

# Merge the income statement and balance sheet first
merge1 = pd.merge(df_income, df_balance, on = list_to_merge_on, how = 'inner')

# Merge previous result with cashflow statement
df_merged = pd.merge(merge1, df_cashflow, on = list_to_merge_on, how = 'inner')

# Reset the index
df_merged.reset_index(inplace=True)

# Make sure that the dates are in correct format
df_merged["Report Date"] = pd.to_datetime(df_merged["Report Date"])
df_merged["Publish Date"] = pd.to_datetime(df_merged["Publish Date"])

print('Merged data matrix shape is: ', df_merged.shape)
# Out:
# Merged data matrix shape is:  (41032, 74)
# time: 188 ms (started: 2022-10-11 23:28:47 +08:00)

# %%
df_merged.head()
# Out:
#   Ticker Report Date  SimFinId Currency  Fiscal Year Fiscal Period_x  \
# 0      A  2016-10-31     45846      USD         2016              Q4
# 1      A  2017-01-31     45846      USD         2017              Q1
# 2      A  2017-04-30     45846      USD         2017              Q2
# 3      A  2017-07-31     45846      USD         2017              Q3
# 4      A  2017-10-31     45846      USD         2017              Q4
#
#   Publish Date Restated Date_x  Shares (Basic)_x  Shares (Diluted)_x  ...  \
# 0   2016-12-20      2018-12-20       324000000.0         328000000.0  ...
# 1   2017-03-08      2018-03-06       322000000.0         326000000.0  ...
# 2   2017-06-06      2018-05-31       321000000.0         325000000.0  ...
# 3   2017-09-06      2018-08-30       321000000.0         326000000.0  ...
# 4   2017-12-21      2018-12-20       324000000.0         327000000.0  ...
#
#    Net Cash from Operating Activities  Change in Fixed Assets & Intangibles  \
# 0                         234000000.0                           -52000000.0
# 1                         116000000.0                           -32000000.0
# 2                         257000000.0                           -43000000.0
# 3                         228000000.0                           -43000000.0
# 4                         288000000.0                           -58000000.0
#
#    Net Change in Long Term Investment  \
# 0                                 0.0
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 0.0
#
#    Net Cash from Acquisitions & Divestitures  \
# 0                                -26000000.0
# 1                                -69000000.0
# 2                                        0.0
# 3                                -57000000.0
# 4                                        0.0
#
#    Net Cash from Investing Activities  Dividends Paid  \
# 0                         -78000000.0     -38000000.0
# 1                        -101000000.0     -42000000.0
# 2                         -43000000.0     -43000000.0
# 3                        -101000000.0     -42000000.0
# 4                         -60000000.0     -43000000.0
#
#    Cash from (Repayment of) Debt  Cash from (Repurchase of) Equity  \
# 0                     27000000.0                       -43000000.0
# 1                     89000000.0                       -93000000.0
# 2                     52000000.0                       -75000000.0
# 3                     39000000.0                        32000000.0
# 4                    -70000000.0                         8000000.0
#
#    Net Cash from Financing Activities  Net Change in Cash
# 0                         -56000000.0            90000000
# 1                         -58000000.0           -48000000
# 2                         -67000000.0           148000000
# 3                          29000000.0           174000000
# 4                        -106000000.0           115000000
#
# [5 rows x 74 columns]
# time: 31 ms (started: 2022-10-11 23:28:47 +08:00)

# %%
df_prices = sf.load_shareprices(variant='daily', market='us')
# Out:
# Dataset "us-shareprices-daily" on disk (4 days old).
# - Loading from disk ... Done!
# time: 9.8 s (started: 2022-10-11 23:28:47 +08:00)

# %%
df_prices.reset_index(inplace=True)
# Out:
# time: 94 ms (started: 2022-10-11 23:28:57 +08:00)

# %%
df_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3172869 entries, 0 to 3172868
# Data columns (total 11 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Ticker              object
#  1   Date                datetime64[ns]
#  2   SimFinId            int64
#  3   Open                float64
#  4   Low                 float64
#  5   High                float64
#  6   Close               float64
#  7   Adj. Close          float64
#  8   Dividend            float64
#  9   Volume              int64
#  10  Shares Outstanding  float64
# dtypes: datetime64[ns](1), float64(7), int64(2), object(1)
# memory usage: 266.3+ MB
# time: 0 ns (started: 2022-10-11 23:28:57 +08:00)

# %%
df_prices.isnull().sum()
# Out:
# Ticker                      0
# Date                        0
# SimFinId                    0
# Open                    21890
# Low                     22342
# High                    21457
# Close                   21864
# Adj. Close              21771
# Dividend              3149382
# Volume                      0
# Shares Outstanding      65841
# dtype: int64
# time: 125 ms (started: 2022-10-11 23:28:57 +08:00)

# %%
df_prices.head()
# Out:
#   Ticker       Date  SimFinId   Open    Low   High  Close  Adj. Close  \
# 0      A 2016-10-06     45846  47.01  46.88  47.43  47.30       45.09
# 1      A 2016-10-07     45846  47.33  46.99  47.49  47.38       45.16
# 2      A 2016-10-10     45846  47.58  47.55  48.15  47.69       45.46
# 3      A 2016-10-11     45846  47.19  45.42  47.19  45.69       43.55
# 4      A 2016-10-12     45846  45.78  45.42  45.81  45.47       43.34
#
#    Dividend   Volume  Shares Outstanding
# 0       NaN  1772801         324384755.0
# 1       NaN  1663127         324384755.0
# 2       NaN  1544958         324384755.0
# 3       NaN  2912537         324384755.0
# 4       NaN  1736076         324384755.0
# time: 15 ms (started: 2022-10-11 23:28:57 +08:00)

# %% [markdown]
# ## Define function to get price of a ticker (or find the nearest price given date)

# %%
# This is a function that takes in the ticker, start date and the prices dataframe
# It will return the ticker, price and date, and transaction value.

def getPrice (ticker, datestart, days_fwd, df=df_prices):
    
    # looks into a window of the next 5 days if date chosen falls on a non-trading day
    window = 5
    
    # returns all the rows between the start date and the window, filtered from df
    rows = df[
    (df["Date"].between(pd.to_datetime(datestart) + pd.Timedelta(days=days_fwd),\
                        pd.to_datetime(datestart) + pd.Timedelta(days=window + days_fwd)))\
        & (df["Ticker"]==ticker)]
    
    # if nothing between start date and window, return nothing
    # NaT stands for Not a Time
    if rows.empty:
        return [ticker, np.float("NaN"), np.datetime64('NaT'), np.float("NaN")]
    
    # else return the first row within the filtered df i.e. closest date
    # returns ticker, open price, date, volume
    else:
        return [ticker, 
                rows.iloc[0]["Open"],\
                rows.iloc[0]["Date"],\
                rows.iloc[0]["Volume"]]
# Out:
# time: 0 ns (started: 2022-10-11 23:29:27 +08:00)

# %% [markdown]
# ### To demonstrate how above function works

# %%
# get daily AAPL data in Oct 2016
df_prices.query("Ticker=='AAPL' & Date<'2016-10-31'")
# Out:
#       Ticker       Date  SimFinId   Open    Low   High  Close  Adj. Close  \
# 10281   AAPL 2016-10-06    111052  28.43  28.28  28.59  28.47       26.55
# 10282   AAPL 2016-10-07    111052  28.58  28.38  28.64  28.52       26.59
# 10283   AAPL 2016-10-10    111052  28.75  28.68  29.19  29.01       27.05
# 10284   AAPL 2016-10-11    111052  29.43  29.05  29.67  29.07       27.11
# 10285   AAPL 2016-10-12    111052  29.34  29.19  29.50  29.34       27.35
# 10286   AAPL 2016-10-13    111052  29.20  28.93  29.36  29.25       27.27
# 10287   AAPL 2016-10-14    111052  29.47  29.28  29.54  29.41       27.42
# 10288   AAPL 2016-10-17    111052  29.33  29.20  29.46  29.39       27.40
# 10289   AAPL 2016-10-18    111052  29.55  29.36  29.55  29.37       27.38
# 10290   AAPL 2016-10-19    111052  29.31  28.45  29.44  29.28       27.30
# 10291   AAPL 2016-10-20    111052  29.21  29.08  29.34  29.27       27.29
# 10292   AAPL 2016-10-21    111052  29.20  29.07  29.23  29.15       27.18
# 10293   AAPL 2016-10-24    111052  29.27  29.25  29.43  29.41       27.43
# 10294   AAPL 2016-10-25    111052  29.49  29.33  29.59  29.56       27.57
# 10295   AAPL 2016-10-26    111052  28.58  28.33  28.93  28.90       26.95
# 10296   AAPL 2016-10-27    111052  28.85  28.52  28.96  28.62       26.69
# 10297   AAPL 2016-10-28    111052  28.47  28.36  28.80  28.43       26.51
#
#        Dividend     Volume  Shares Outstanding
# 10281       NaN  115117252        2.134466e+10
# 10282       NaN   97433772        2.134466e+10
# 10283       NaN  144943824        2.134466e+10
# 10284       NaN  256164172        2.134466e+10
# 10285       NaN  150347148        2.134466e+10
# 10286       NaN  140769624        2.134466e+10
# 10287       NaN  142608764        2.132925e+10
# 10288       NaN   94499584        2.132925e+10
# 10289       NaN   98213912        2.132925e+10
# 10290       NaN   80138376        2.132925e+10
# 10291       NaN   96503204        2.132925e+10
# 10292       NaN   92770660        2.132925e+10
# 10293       NaN   94154692        2.132925e+10
# 10294       NaN  192515880        2.132925e+10
# 10295       NaN  264536876        2.132925e+10
# 10296       NaN  138248180        2.132925e+10
# 10297       NaN  151446648        2.132925e+10
# time: 188 ms (started: 2022-10-11 23:29:27 +08:00)

# %%
# use function to get price data from AAPL 10 Oct 2016
getPrice('AAPL', '2016-10-10', 0, df_prices)
# Out:
# ['AAPL', 28.75, Timestamp('2016-10-10 00:00:00'), 144943824]
# time: 172 ms (started: 2022-10-11 23:29:27 +08:00)

# %%
# use function to get price date from AAPL 10 Oct 2016
# as 09 Oct 2016 is non trading day, function will find the price info from 12 Sep instead
getPrice('AAPL', '2016-10-09', 0, df_prices)
# Out:
# ['AAPL', 28.75, Timestamp('2016-10-10 00:00:00'), 144943824]
# time: 156 ms (started: 2022-10-11 23:29:27 +08:00)

# %%
# use function to get APPL price date 30 days in the future using the days_adj parameter
getPrice('AAPL', '2016-09-10', 30, df_prices)
# Out:
# ['AAPL', 28.75, Timestamp('2016-10-10 00:00:00'), 144943824]
# time: 156 ms (started: 2022-10-11 23:29:27 +08:00)

# %% [markdown]
# **At this point, we want to combine the fundamental data and the price data together, such that we have the price data on each Report Date. However, sometimes the Report Date falls on a weekend/non-trading day, so we need to find another way to get the closest price data. Below we will attempt to do this.**

# %%
# all the fundemental data that we have combined so far
pd.set_option('display.max_columns', 200)
df_merged.head()
# Out:
#   Ticker Report Date  SimFinId Currency  Fiscal Year Fiscal Period_x  \
# 0      A  2016-10-31     45846      USD         2016              Q4
# 1      A  2017-01-31     45846      USD         2017              Q1
# 2      A  2017-04-30     45846      USD         2017              Q2
# 3      A  2017-07-31     45846      USD         2017              Q3
# 4      A  2017-10-31     45846      USD         2017              Q4
#
#   Publish Date Restated Date_x  Shares (Basic)_x  Shares (Diluted)_x  \
# 0   2016-12-20      2018-12-20       324000000.0         328000000.0
# 1   2017-03-08      2018-03-06       322000000.0         326000000.0
# 2   2017-06-06      2018-05-31       321000000.0         325000000.0
# 3   2017-09-06      2018-08-30       321000000.0         326000000.0
# 4   2017-12-21      2018-12-20       324000000.0         327000000.0
#
#         Revenue  Cost of Revenue  Gross Profit  Operating Expenses  \
# 0  1.111000e+09     -523000000.0   588000000.0        -405000000.0
# 1  1.067000e+09     -493000000.0   574000000.0        -368000000.0
# 2  1.102000e+09     -510000000.0   592000000.0        -391000000.0
# 3  1.114000e+09     -518000000.0   596000000.0        -395000000.0
# 4  1.189000e+09     -542000000.0   647000000.0        -414000000.0
#
#    Selling, General & Administrative  Research & Development  \
# 0                       -321000000.0             -84000000.0
# 1                       -289000000.0             -79000000.0
# 2                       -307000000.0             -84000000.0
# 3                       -308000000.0             -87000000.0
# 4                       -325000000.0             -89000000.0
#
#    Depreciation & Amortization_x  Operating Income (Loss)  \
# 0                            NaN              183000000.0
# 1                            NaN              206000000.0
# 2                            NaN              201000000.0
# 3                            NaN              201000000.0
# 4                            NaN              233000000.0
#
#    Non-Operating Income (Loss)  Interest Expense, Net  \
# 0                  -32000000.0            -16000000.0
# 1                  -13000000.0            -16000000.0
# 2                  -10000000.0            -15000000.0
# 3                   -8000000.0            -13000000.0
# 4                   -7000000.0            -13000000.0
#
#    Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  Pretax Income (Loss)  \
# 0                   151000000                      NaN             151000000
# 1                   193000000                      NaN             193000000
# 2                   191000000                      NaN             191000000
# 3                   193000000                      NaN             193000000
# 4                   226000000                      NaN             226000000
#
#    Income Tax (Expense) Benefit, Net  \
# 0                        -25000000.0
# 1                        -25000000.0
# 2                        -27000000.0
# 3                        -18000000.0
# 4                        -49000000.0
#
#    Income (Loss) from Continuing Operations  Net Extraordinary Gains (Losses)  \
# 0                                 126000000                               NaN
# 1                                 168000000                               NaN
# 2                                 164000000                               NaN
# 3                                 175000000                               NaN
# 4                                 177000000                               NaN
#
#    Net Income  Net Income (Common) Fiscal Period_y Restated Date_y  \
# 0   126000000            126000000              Q4      2017-12-21
# 1   168000000            168000000              Q1      2017-03-08
# 2   164000000            164000000              Q2      2017-06-06
# 3   175000000            175000000              Q3      2017-09-06
# 4   177000000            177000000              Q4      2018-12-20
#
#    Shares (Basic)_y  Shares (Diluted)_y  \
# 0       324000000.0         328000000.0
# 1       322000000.0         326000000.0
# 2       321000000.0         325000000.0
# 3       321000000.0         326000000.0
# 4       324000000.0         327000000.0
#
#    Cash, Cash Equivalents & Short Term Investments  \
# 0                                     2.289000e+09
# 1                                     2.241000e+09
# 2                                     2.389000e+09
# 3                                     2.563000e+09
# 4                                     2.678000e+09
#
#    Accounts & Notes Receivable  Inventories  Total Current Assets  \
# 0                  631000000.0  533000000.0          3.635000e+09
# 1                  653000000.0  551000000.0          3.635000e+09
# 2                  677000000.0  548000000.0          3.800000e+09
# 3                  678000000.0  566000000.0          3.996000e+09
# 4                  724000000.0  575000000.0          4.169000e+09
#
#    Property, Plant & Equipment, Net  Long Term Investments & Receivables  \
# 0                       639000000.0                          135000000.0
# 1                       653000000.0                          133000000.0
# 2                       675000000.0                          134000000.0
# 3                       716000000.0                          137000000.0
# 4                       757000000.0                          138000000.0
#
#    Other Long Term Assets  Total Noncurrent Assets  Total Assets  \
# 0            3.385000e+09             4.159000e+09    7794000000
# 1            3.451000e+09             4.237000e+09    7872000000
# 2            3.407000e+09             4.216000e+09    8016000000
# 3            3.412000e+09             4.265000e+09    8261000000
# 4            3.362000e+09             4.257000e+09    8426000000
#
#    Payables & Accruals  Short Term Debt  Total Current Liabilities  \
# 0          257000000.0              0.0                  945000000
# 1          268000000.0      190000000.0                 1089000000
# 2          265000000.0      241000000.0                 1187000000
# 3          289000000.0      280000000.0                 1241000000
# 4          305000000.0      210000000.0                 1263000000
#
#    Long Term Debt  Total Noncurrent Liabilities  Total Liabilities  \
# 0    1.904000e+09                  2.603000e+09         3548000000
# 1    1.802000e+09                  2.483000e+09         3572000000
# 2    1.802000e+09                  2.454000e+09         3641000000
# 3    1.801000e+09                  2.409000e+09         3650000000
# 4    1.801000e+09                  2.328000e+09         3591000000
#
#    Share Capital & Additional Paid-In Capital  Treasury Stock  \
# 0                                9.165000e+09   -1.050800e+10
# 1                                5.239000e+09    0.000000e+00
# 2                                5.242000e+09    0.000000e+00
# 3                                5.285000e+09    0.000000e+00
# 4                                5.303000e+09             NaN
#
#    Retained Earnings  Total Equity  Total Liabilities & Equity Fiscal Period  \
# 0       6.089000e+09  4.246000e+09                  7794000000            Q4
# 1      -4.530000e+08  4.300000e+09                  7872000000            Q1
# 2      -3.930000e+08  4.375000e+09                  8016000000            Q2
# 3      -2.600000e+08  4.611000e+09                  8261000000            Q3
# 4      -1.260000e+08  4.835000e+09                  8426000000            Q4
#
#   Restated Date  Shares (Basic)  Shares (Diluted)  Net Income/Starting Line  \
# 0    2018-12-20     324000000.0       328000000.0               126000000.0
# 1    2018-03-06     322000000.0       326000000.0               168000000.0
# 2    2018-05-31     321000000.0       325000000.0               164000000.0
# 3    2018-08-30     321000000.0       326000000.0               175000000.0
# 4    2018-12-20     324000000.0       327000000.0               177000000.0
#
#    Depreciation & Amortization_y  Non-Cash Items  Change in Working Capital  \
# 0                     56000000.0       2000000.0                 50000000.0
# 1                     55000000.0      45000000.0               -152000000.0
# 2                     54000000.0      27000000.0                 12000000.0
# 3                     51000000.0      83000000.0                -81000000.0
# 4                     52000000.0      38000000.0                 21000000.0
#
#    Change in Accounts Receivable  Change in Inventories  \
# 0                    -52000000.0              4000000.0
# 1                    -31000000.0            -26000000.0
# 2                    -17000000.0             -3000000.0
# 3                     19000000.0            -17000000.0
# 4                    -52000000.0            -15000000.0
#
#    Change in Accounts Payable  Change in Other  \
# 0                  12000000.0       86000000.0
# 1                   9000000.0     -104000000.0
# 2                  -3000000.0       35000000.0
# 3                   5000000.0      -88000000.0
# 4                  -9000000.0       97000000.0
#
#    Net Cash from Operating Activities  Change in Fixed Assets & Intangibles  \
# 0                         234000000.0                           -52000000.0
# 1                         116000000.0                           -32000000.0
# 2                         257000000.0                           -43000000.0
# 3                         228000000.0                           -43000000.0
# 4                         288000000.0                           -58000000.0
#
#    Net Change in Long Term Investment  \
# 0                                 0.0
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 0.0
#
#    Net Cash from Acquisitions & Divestitures  \
# 0                                -26000000.0
# 1                                -69000000.0
# 2                                        0.0
# 3                                -57000000.0
# 4                                        0.0
#
#    Net Cash from Investing Activities  Dividends Paid  \
# 0                         -78000000.0     -38000000.0
# 1                        -101000000.0     -42000000.0
# 2                         -43000000.0     -43000000.0
# 3                        -101000000.0     -42000000.0
# 4                         -60000000.0     -43000000.0
#
#    Cash from (Repayment of) Debt  Cash from (Repurchase of) Equity  \
# 0                     27000000.0                       -43000000.0
# 1                     89000000.0                       -93000000.0
# 2                     52000000.0                       -75000000.0
# 3                     39000000.0                        32000000.0
# 4                    -70000000.0                         8000000.0
#
#    Net Cash from Financing Activities  Net Change in Cash
# 0                         -56000000.0            90000000
# 1                         -58000000.0           -48000000
# 2                         -67000000.0           148000000
# 3                          29000000.0           174000000
# 4                        -106000000.0           115000000
# time: 46 ms (started: 2022-10-11 23:29:27 +08:00)

# %%
# all the price data that we have combined so far
df_prices.head()
# Out:
#   Ticker       Date  SimFinId   Open    Low   High  Close  Adj. Close  \
# 0      A 2016-10-06     45846  47.01  46.88  47.43  47.30       45.09
# 1      A 2016-10-07     45846  47.33  46.99  47.49  47.38       45.16
# 2      A 2016-10-10     45846  47.58  47.55  48.15  47.69       45.46
# 3      A 2016-10-11     45846  47.19  45.42  47.19  45.69       43.55
# 4      A 2016-10-12     45846  45.78  45.42  45.81  45.47       43.34
#
#    Dividend   Volume  Shares Outstanding
# 0       NaN  1772801         324384755.0
# 1       NaN  1663127         324384755.0
# 2       NaN  1544958         324384755.0
# 3       NaN  2912537         324384755.0
# 4       NaN  1736076         324384755.0
# time: 0 ns (started: 2022-10-11 23:29:27 +08:00)

# %%
# We want to find the price of each ticker on each Report Date. 
# To do this, we create a new dataframe using the above info.

df_report_date = df_merged[['Ticker', 'Report Date']]
df_price_date = df_prices[['Ticker', 'Date', 'Open', 'Volume']]

# In addition, we add five more columns for 5 days after reporting date
df_report_date['ReportDate+1'] = df_report_date['Report Date'] + pd.Timedelta(days=1)
df_report_date['ReportDate+2'] = df_report_date['Report Date'] + pd.Timedelta(days=2)
df_report_date['ReportDate+3'] = df_report_date['Report Date'] + pd.Timedelta(days=3)
df_report_date['ReportDate+4'] = df_report_date['Report Date'] + pd.Timedelta(days=4)
df_report_date['ReportDate+5'] = df_report_date['Report Date'] + pd.Timedelta(days=5)
# Out:
# time: 78 ms (started: 2022-10-11 23:29:27 +08:00)

# %%
# Merge the two subsets above using outer join only on the REPORT DATE
price_on_report_date = pd.merge(df_report_date, df_price_date, how='outer',
                                left_on=['Ticker','Report Date'], right_on=['Ticker','Date'])
# Out:
# time: 907 ms (started: 2022-10-11 23:29:28 +08:00)

# %%
price_on_report_date.notnull().sum()
# Out:
# Ticker          3188969
# Report Date       41032
# ReportDate+1      41032
# ReportDate+2      41032
# ReportDate+3      41032
# ReportDate+4      41032
# ReportDate+5      41032
# Date            3172869
# Open            3150979
# Volume          3172869
# dtype: int64
# time: 125 ms (started: 2022-10-11 23:29:28 +08:00)

# %%
price_on_report_date.head(20)
# Out:
#    Ticker Report Date ReportDate+1 ReportDate+2 ReportDate+3 ReportDate+4  \
# 0       A  2016-10-31   2016-11-01   2016-11-02   2016-11-03   2016-11-04
# 1       A  2017-01-31   2017-02-01   2017-02-02   2017-02-03   2017-02-04
# 2       A  2017-04-30   2017-05-01   2017-05-02   2017-05-03   2017-05-04
# 3       A  2017-07-31   2017-08-01   2017-08-02   2017-08-03   2017-08-04
# 4       A  2017-10-31   2017-11-01   2017-11-02   2017-11-03   2017-11-04
# 5       A  2018-01-31   2018-02-01   2018-02-02   2018-02-03   2018-02-04
# 6       A  2018-04-30   2018-05-01   2018-05-02   2018-05-03   2018-05-04
# 7       A  2018-07-31   2018-08-01   2018-08-02   2018-08-03   2018-08-04
# 8       A  2018-10-31   2018-11-01   2018-11-02   2018-11-03   2018-11-04
# 9       A  2019-01-31   2019-02-01   2019-02-02   2019-02-03   2019-02-04
# 10      A  2019-04-30   2019-05-01   2019-05-02   2019-05-03   2019-05-04
# 11      A  2019-07-31   2019-08-01   2019-08-02   2019-08-03   2019-08-04
# 12      A  2019-10-31   2019-11-01   2019-11-02   2019-11-03   2019-11-04
# 13      A  2020-01-31   2020-02-01   2020-02-02   2020-02-03   2020-02-04
# 14      A  2020-04-30   2020-05-01   2020-05-02   2020-05-03   2020-05-04
# 15      A  2020-07-31   2020-08-01   2020-08-02   2020-08-03   2020-08-04
# 16      A  2020-10-31   2020-11-01   2020-11-02   2020-11-03   2020-11-04
# 17      A  2021-01-31   2021-02-01   2021-02-02   2021-02-03   2021-02-04
# 18      A  2021-04-30   2021-05-01   2021-05-02   2021-05-03   2021-05-04
# 19      A  2021-07-31   2021-08-01   2021-08-02   2021-08-03   2021-08-04
#
#    ReportDate+5       Date    Open     Volume
# 0    2016-11-05 2016-10-31   43.33  1556762.0
# 1    2017-02-05 2017-01-31   48.04  2552612.0
# 2    2017-05-05        NaT     NaN        NaN
# 3    2017-08-05 2017-07-31   60.32  1038744.0
# 4    2017-11-05 2017-10-31   67.74  1609938.0
# 5    2018-02-05 2018-01-31   73.77  1949108.0
# 6    2018-05-05 2018-04-30   66.49  2277705.0
# 7    2018-08-05 2018-07-31   64.93  2539265.0
# 8    2018-11-05 2018-10-31   64.35  3820987.0
# 9    2019-02-05 2019-01-31   75.21  2951321.0
# 10   2019-05-05 2019-04-30   77.44  1726239.0
# 11   2019-08-05 2019-07-31   70.19  3846063.0
# 12   2019-11-05 2019-10-31   76.00   970472.0
# 13   2020-02-05 2020-01-31   84.03  2850446.0
# 14   2020-05-05 2020-04-30   77.96  1795163.0
# 15   2020-08-05 2020-07-31   95.94  1551785.0
# 16   2020-11-05        NaT     NaN        NaN
# 17   2021-02-05        NaT     NaN        NaN
# 18   2021-05-05 2021-04-30  133.90  1514162.0
# 19   2021-08-05        NaT     NaN        NaN
# time: 16 ms (started: 2022-10-11 23:29:29 +08:00)

# %% [markdown]
# As we can see from above, some reporting dates do not have price data, so we need to fill it with price data from the closest date available (either ReportDate+1 or ReportDate+2)

# %%
# merge the two subsets above using outer join on REPORT DATE + 1
price_on_report_date1 = pd.merge(price_on_report_date, df_price_date, how='outer',
                                left_on=['Ticker','ReportDate+1'], right_on=['Ticker','Date'])
# Out:
# time: 1.66 s (started: 2022-10-11 23:29:29 +08:00)

# %%
# merge the two subsets above using outer join on REPORT DATE + 2
price_on_report_date2 = pd.merge(price_on_report_date1, df_price_date, how='outer',
                                left_on=['Ticker','ReportDate+2'], right_on=['Ticker','Date'])
# Out:
# time: 2.62 s (started: 2022-10-11 23:29:30 +08:00)

# %%
# merge the two subsets above using outer join on REPORT DATE + 3
price_on_report_date3 = pd.merge(price_on_report_date2, df_price_date, how='outer',
                                left_on=['Ticker','ReportDate+3'], right_on=['Ticker','Date'])
# Out:
# time: 6.06 s (started: 2022-10-11 23:29:33 +08:00)

# %%
# merge the two subsets above using outer join on REPORT DATE + 4
price_on_report_date4 = pd.merge(price_on_report_date3, df_price_date, how='outer',
                                left_on=['Ticker','ReportDate+4'], right_on=['Ticker','Date'])
# Out:
# time: 16.5 s (started: 2022-10-11 23:29:39 +08:00)

# %%
# merge the two subsets above using outer join on REPORT DATE + 5
price_on_report_date5 = pd.merge(price_on_report_date4, df_price_date, how='outer',
                                left_on=['Ticker','ReportDate+5'], right_on=['Ticker','Date'])
# Out:
# time: 23.5 s (started: 2022-10-11 23:29:56 +08:00)

# %% [markdown]
# **In the final "price_on_report_date5" merged dataframe, we have managed to get the price and volume information from the closest available trading date. We will do further cleaning to simplify this.**

# %%
# There are some null values in the first "Open" and "Volume" columns
price_on_report_date5.head(20)
# Out:
#    Ticker Report Date ReportDate+1 ReportDate+2 ReportDate+3 ReportDate+4  \
# 0       A  2016-10-31   2016-11-01   2016-11-02   2016-11-03   2016-11-04
# 1       A  2017-01-31   2017-02-01   2017-02-02   2017-02-03   2017-02-04
# 2       A  2017-04-30   2017-05-01   2017-05-02   2017-05-03   2017-05-04
# 3       A  2017-07-31   2017-08-01   2017-08-02   2017-08-03   2017-08-04
# 4       A  2017-10-31   2017-11-01   2017-11-02   2017-11-03   2017-11-04
# 5       A  2018-01-31   2018-02-01   2018-02-02   2018-02-03   2018-02-04
# 6       A  2018-04-30   2018-05-01   2018-05-02   2018-05-03   2018-05-04
# 7       A  2018-07-31   2018-08-01   2018-08-02   2018-08-03   2018-08-04
# 8       A  2018-10-31   2018-11-01   2018-11-02   2018-11-03   2018-11-04
# 9       A  2019-01-31   2019-02-01   2019-02-02   2019-02-03   2019-02-04
# 10      A  2019-04-30   2019-05-01   2019-05-02   2019-05-03   2019-05-04
# 11      A  2019-07-31   2019-08-01   2019-08-02   2019-08-03   2019-08-04
# 12      A  2019-10-31   2019-11-01   2019-11-02   2019-11-03   2019-11-04
# 13      A  2020-01-31   2020-02-01   2020-02-02   2020-02-03   2020-02-04
# 14      A  2020-04-30   2020-05-01   2020-05-02   2020-05-03   2020-05-04
# 15      A  2020-07-31   2020-08-01   2020-08-02   2020-08-03   2020-08-04
# 16      A  2020-10-31   2020-11-01   2020-11-02   2020-11-03   2020-11-04
# 17      A  2021-01-31   2021-02-01   2021-02-02   2021-02-03   2021-02-04
# 18      A  2021-04-30   2021-05-01   2021-05-02   2021-05-03   2021-05-04
# 19      A  2021-07-31   2021-08-01   2021-08-02   2021-08-03   2021-08-04
#
#    ReportDate+5     Date_x  Open_x   Volume_x     Date_y  Open_y   Volume_y  \
# 0    2016-11-05 2016-10-31   43.33  1556762.0 2016-11-01   43.73  2133116.0
# 1    2017-02-05 2017-01-31   48.04  2552612.0 2017-02-01   48.93  2244604.0
# 2    2017-05-05        NaT     NaN        NaN 2017-05-01   55.50  1897018.0
# 3    2017-08-05 2017-07-31   60.32  1038744.0 2017-08-01   60.04  1323605.0
# 4    2017-11-05 2017-10-31   67.74  1609938.0 2017-11-01   68.20  1357307.0
# 5    2018-02-05 2018-01-31   73.77  1949108.0 2018-02-01   73.18  1978455.0
# 6    2018-05-05 2018-04-30   66.49  2277705.0 2018-05-01   65.63  3135146.0
# 7    2018-08-05 2018-07-31   64.93  2539265.0 2018-08-01   65.84  2679180.0
# 8    2018-11-05 2018-10-31   64.35  3820987.0 2018-11-01   65.07  1882438.0
# 9    2019-02-05 2019-01-31   75.21  2951321.0 2019-02-01   76.16  1343915.0
# 10   2019-05-05 2019-04-30   77.44  1726239.0 2019-05-01   78.49  1078572.0
# 11   2019-08-05 2019-07-31   70.19  3846063.0 2019-08-01   69.63  2494123.0
# 12   2019-11-05 2019-10-31   76.00   970472.0 2019-11-01   76.51  1106264.0
# 13   2020-02-05 2020-01-31   84.03  2850446.0        NaT     NaN        NaN
# 14   2020-05-05 2020-04-30   77.96  1795163.0 2020-05-01   75.55  1618594.0
# 15   2020-08-05 2020-07-31   95.94  1551785.0        NaT     NaN        NaN
# 16   2020-11-05        NaT     NaN        NaN        NaT     NaN        NaN
# 17   2021-02-05        NaT     NaN        NaN 2021-02-01  120.69  1292732.0
# 18   2021-05-05 2021-04-30  133.90  1514162.0        NaT     NaN        NaN
# 19   2021-08-05        NaT     NaN        NaN        NaT     NaN        NaN
#
#        Date_x  Open_x   Volume_x     Date_y  Open_y   Volume_y     Date_x  \
# 0  2016-11-02   43.47  2240428.0 2016-11-03   43.33  2510054.0 2016-11-04
# 1  2017-02-02   48.88  1352525.0 2017-02-03   49.09  1191855.0        NaT
# 2  2017-05-02   55.85  1673735.0 2017-05-03   55.68  1702565.0 2017-05-04
# 3  2017-08-02   60.00  1121493.0 2017-08-03   60.15   982876.0 2017-08-04
# 4  2017-11-02   68.08  1854678.0 2017-11-03   68.09  1070662.0        NaT
# 5  2018-02-02   72.32  1947113.0        NaT     NaN        NaN        NaT
# 6  2018-05-02   66.00  2240482.0 2018-05-03   65.77  2365851.0 2018-05-04
# 7  2018-08-02   64.75  2263190.0 2018-08-03   65.50  1857308.0        NaT
# 8  2018-11-02   65.80  2272114.0        NaT     NaN        NaN        NaT
# 9         NaT     NaN        NaN        NaT     NaN        NaN 2019-02-04
# 10 2019-05-02   77.41   946764.0 2019-05-03   78.58  1303198.0        NaT
# 11 2019-08-02   69.12  2803508.0        NaT     NaN        NaN        NaT
# 12        NaT     NaN        NaN        NaT     NaN        NaN 2019-11-04
# 13        NaT     NaN        NaN 2020-02-03   83.29  1919771.0 2020-02-04
# 14        NaT     NaN        NaN        NaT     NaN        NaN 2020-05-04
# 15        NaT     NaN        NaN 2020-08-03   96.94  1994325.0 2020-08-04
# 16 2020-11-02  103.52  1572506.0 2020-11-03  106.43  1175149.0 2020-11-04
# 17 2021-02-02  122.50  1429186.0 2021-02-03  123.50  1448494.0 2021-02-04
# 18        NaT     NaN        NaN 2021-05-03  134.29  1032021.0 2021-05-04
# 19 2021-08-02  154.05  1438321.0 2021-08-03  153.71  1859655.0 2021-08-04
#
#     Open_x   Volume_x     Date_y  Open_y   Volume_y
# 0    43.69  2220908.0        NaT     NaN        NaN
# 1      NaN        NaN        NaT     NaN        NaN
# 2    56.20  2609703.0 2017-05-05   56.85  1567046.0
# 3    60.52   778762.0        NaT     NaN        NaN
# 4      NaN        NaN        NaT     NaN        NaN
# 5      NaN        NaN 2018-02-05   70.86  2797258.0
# 6    66.03  1331017.0        NaT     NaN        NaN
# 7      NaN        NaN        NaT     NaN        NaN
# 8      NaN        NaN 2018-11-05   66.03  2348704.0
# 9    76.18  2245893.0 2019-02-05   75.80  1593537.0
# 10     NaN        NaN        NaT     NaN        NaN
# 11     NaN        NaN 2019-08-05   66.84  3273115.0
# 12   77.68  1010174.0 2019-11-05   76.82  2362034.0
# 13   82.85  1676020.0 2020-02-05   84.53  2345127.0
# 14   74.28  1555396.0 2020-05-05   74.91  1476069.0
# 15   98.71   779236.0 2020-08-05   98.09   958344.0
# 16  108.07  1357382.0 2020-11-05  110.57  1143082.0
# 17  122.51  1251162.0 2021-02-05  124.51  1919710.0
# 18  132.12  1752428.0 2021-05-05  132.09  1430600.0
# 19  153.96  1786735.0 2021-08-05  154.46  1667633.0
# time: 125 ms (started: 2022-10-11 23:30:19 +08:00)

# %%
# If there is no price on Report date, then take the price on Report date + 1.
# If there is no price on Report date + 1, then take the price on Report date + 2 and so on.
# Similarly, if there is no volume on Report date, then take the volume on Report date + 1.
# If there is no volume on Report date + 1, then take the volume on Report date + 2 and so on.

for i in range(1,6):
    price_on_report_date5.iloc[:,8] = np.where(price_on_report_date5.iloc[:,8].isnull(),
                                               price_on_report_date5.iloc[:,8+i*3],
                                               price_on_report_date5.iloc[:,8])
    
    price_on_report_date5.iloc[:,9] = np.where(price_on_report_date5.iloc[:,9].isnull(),
                                               price_on_report_date5.iloc[:,9+i*3],
                                               price_on_report_date5.iloc[:,9])
    i+=1
# Out:
# time: 1.11 s (started: 2022-10-11 23:30:19 +08:00)

# %%
# Basically, the first Open and Volume are the columns we want to keep.
# These columns should have Price and Volume data that is close to the Report Date.
price_on_report_date5.head(20)
# Out:
#    Ticker Report Date ReportDate+1 ReportDate+2 ReportDate+3 ReportDate+4  \
# 0       A  2016-10-31   2016-11-01   2016-11-02   2016-11-03   2016-11-04
# 1       A  2017-01-31   2017-02-01   2017-02-02   2017-02-03   2017-02-04
# 2       A  2017-04-30   2017-05-01   2017-05-02   2017-05-03   2017-05-04
# 3       A  2017-07-31   2017-08-01   2017-08-02   2017-08-03   2017-08-04
# 4       A  2017-10-31   2017-11-01   2017-11-02   2017-11-03   2017-11-04
# 5       A  2018-01-31   2018-02-01   2018-02-02   2018-02-03   2018-02-04
# 6       A  2018-04-30   2018-05-01   2018-05-02   2018-05-03   2018-05-04
# 7       A  2018-07-31   2018-08-01   2018-08-02   2018-08-03   2018-08-04
# 8       A  2018-10-31   2018-11-01   2018-11-02   2018-11-03   2018-11-04
# 9       A  2019-01-31   2019-02-01   2019-02-02   2019-02-03   2019-02-04
# 10      A  2019-04-30   2019-05-01   2019-05-02   2019-05-03   2019-05-04
# 11      A  2019-07-31   2019-08-01   2019-08-02   2019-08-03   2019-08-04
# 12      A  2019-10-31   2019-11-01   2019-11-02   2019-11-03   2019-11-04
# 13      A  2020-01-31   2020-02-01   2020-02-02   2020-02-03   2020-02-04
# 14      A  2020-04-30   2020-05-01   2020-05-02   2020-05-03   2020-05-04
# 15      A  2020-07-31   2020-08-01   2020-08-02   2020-08-03   2020-08-04
# 16      A  2020-10-31   2020-11-01   2020-11-02   2020-11-03   2020-11-04
# 17      A  2021-01-31   2021-02-01   2021-02-02   2021-02-03   2021-02-04
# 18      A  2021-04-30   2021-05-01   2021-05-02   2021-05-03   2021-05-04
# 19      A  2021-07-31   2021-08-01   2021-08-02   2021-08-03   2021-08-04
#
#    ReportDate+5     Date_x  Open_x   Volume_x     Date_y  Open_y   Volume_y  \
# 0    2016-11-05 2016-10-31   43.33  1556762.0 2016-11-01   43.73  2133116.0
# 1    2017-02-05 2017-01-31   48.04  2552612.0 2017-02-01   48.93  2244604.0
# 2    2017-05-05        NaT   55.50  1897018.0 2017-05-01   55.50  1897018.0
# 3    2017-08-05 2017-07-31   60.32  1038744.0 2017-08-01   60.04  1323605.0
# 4    2017-11-05 2017-10-31   67.74  1609938.0 2017-11-01   68.20  1357307.0
# 5    2018-02-05 2018-01-31   73.77  1949108.0 2018-02-01   73.18  1978455.0
# 6    2018-05-05 2018-04-30   66.49  2277705.0 2018-05-01   65.63  3135146.0
# 7    2018-08-05 2018-07-31   64.93  2539265.0 2018-08-01   65.84  2679180.0
# 8    2018-11-05 2018-10-31   64.35  3820987.0 2018-11-01   65.07  1882438.0
# 9    2019-02-05 2019-01-31   75.21  2951321.0 2019-02-01   76.16  1343915.0
# 10   2019-05-05 2019-04-30   77.44  1726239.0 2019-05-01   78.49  1078572.0
# 11   2019-08-05 2019-07-31   70.19  3846063.0 2019-08-01   69.63  2494123.0
# 12   2019-11-05 2019-10-31   76.00   970472.0 2019-11-01   76.51  1106264.0
# 13   2020-02-05 2020-01-31   84.03  2850446.0        NaT     NaN        NaN
# 14   2020-05-05 2020-04-30   77.96  1795163.0 2020-05-01   75.55  1618594.0
# 15   2020-08-05 2020-07-31   95.94  1551785.0        NaT     NaN        NaN
# 16   2020-11-05        NaT  103.52  1572506.0        NaT     NaN        NaN
# 17   2021-02-05        NaT  120.69  1292732.0 2021-02-01  120.69  1292732.0
# 18   2021-05-05 2021-04-30  133.90  1514162.0        NaT     NaN        NaN
# 19   2021-08-05        NaT  154.05  1438321.0        NaT     NaN        NaN
#
#        Date_x  Open_x   Volume_x     Date_y  Open_y   Volume_y     Date_x  \
# 0  2016-11-02   43.47  2240428.0 2016-11-03   43.33  2510054.0 2016-11-04
# 1  2017-02-02   48.88  1352525.0 2017-02-03   49.09  1191855.0        NaT
# 2  2017-05-02   55.85  1673735.0 2017-05-03   55.68  1702565.0 2017-05-04
# 3  2017-08-02   60.00  1121493.0 2017-08-03   60.15   982876.0 2017-08-04
# 4  2017-11-02   68.08  1854678.0 2017-11-03   68.09  1070662.0        NaT
# 5  2018-02-02   72.32  1947113.0        NaT     NaN        NaN        NaT
# 6  2018-05-02   66.00  2240482.0 2018-05-03   65.77  2365851.0 2018-05-04
# 7  2018-08-02   64.75  2263190.0 2018-08-03   65.50  1857308.0        NaT
# 8  2018-11-02   65.80  2272114.0        NaT     NaN        NaN        NaT
# 9         NaT     NaN        NaN        NaT     NaN        NaN 2019-02-04
# 10 2019-05-02   77.41   946764.0 2019-05-03   78.58  1303198.0        NaT
# 11 2019-08-02   69.12  2803508.0        NaT     NaN        NaN        NaT
# 12        NaT     NaN        NaN        NaT     NaN        NaN 2019-11-04
# 13        NaT     NaN        NaN 2020-02-03   83.29  1919771.0 2020-02-04
# 14        NaT     NaN        NaN        NaT     NaN        NaN 2020-05-04
# 15        NaT     NaN        NaN 2020-08-03   96.94  1994325.0 2020-08-04
# 16 2020-11-02  103.52  1572506.0 2020-11-03  106.43  1175149.0 2020-11-04
# 17 2021-02-02  122.50  1429186.0 2021-02-03  123.50  1448494.0 2021-02-04
# 18        NaT     NaN        NaN 2021-05-03  134.29  1032021.0 2021-05-04
# 19 2021-08-02  154.05  1438321.0 2021-08-03  153.71  1859655.0 2021-08-04
#
#     Open_x   Volume_x     Date_y  Open_y   Volume_y
# 0    43.69  2220908.0        NaT     NaN        NaN
# 1      NaN        NaN        NaT     NaN        NaN
# 2    56.20  2609703.0 2017-05-05   56.85  1567046.0
# 3    60.52   778762.0        NaT     NaN        NaN
# 4      NaN        NaN        NaT     NaN        NaN
# 5      NaN        NaN 2018-02-05   70.86  2797258.0
# 6    66.03  1331017.0        NaT     NaN        NaN
# 7      NaN        NaN        NaT     NaN        NaN
# 8      NaN        NaN 2018-11-05   66.03  2348704.0
# 9    76.18  2245893.0 2019-02-05   75.80  1593537.0
# 10     NaN        NaN        NaT     NaN        NaN
# 11     NaN        NaN 2019-08-05   66.84  3273115.0
# 12   77.68  1010174.0 2019-11-05   76.82  2362034.0
# 13   82.85  1676020.0 2020-02-05   84.53  2345127.0
# 14   74.28  1555396.0 2020-05-05   74.91  1476069.0
# 15   98.71   779236.0 2020-08-05   98.09   958344.0
# 16  108.07  1357382.0 2020-11-05  110.57  1143082.0
# 17  122.51  1251162.0 2021-02-05  124.51  1919710.0
# 18  132.12  1752428.0 2021-05-05  132.09  1430600.0
# 19  153.96  1786735.0 2021-08-05  154.46  1667633.0
# time: 31 ms (started: 2022-10-11 23:30:20 +08:00)

# %%
# Drop off all unnecessary columns first
# Or rather keep all the necessary columns
df_reportdate = price_on_report_date5.iloc[:,[0,1,8,9]]
# Out:
# time: 468 ms (started: 2022-10-11 23:30:20 +08:00)

# %%
df_reportdate
# Out:
#          Ticker Report Date  Open_x   Volume_x
# 0             A  2016-10-31   43.33  1556762.0
# 1             A  2017-01-31   48.04  2552612.0
# 2             A  2017-04-30   55.50  1897018.0
# 3             A  2017-07-31   60.32  1038744.0
# 4             A  2017-10-31   67.74  1609938.0
# ...         ...         ...     ...        ...
# 18926952   ZYXI         NaT   10.76   195093.0
# 18926953   ZYXI         NaT   10.58   252514.0
# 18926954   ZYXI         NaT   10.28   518118.0
# 18926955   ZYXI         NaT   10.01   539125.0
# 18926956   ZYXI         NaT    9.96   154434.0
#
# [18926957 rows x 4 columns]
# time: 31 ms (started: 2022-10-11 23:30:21 +08:00)

# %%
# Rename the columns
df_reportdate = df_reportdate.rename(columns={'Open_x':'Open',
                                            'Volume_x':'Volume'})
# Out:
# time: 156 ms (started: 2022-10-11 23:30:21 +08:00)

# %%
# Drop off all null rows without a Report Date
df_reportdate = df_reportdate[df_reportdate['Report Date'].notnull()]
# Out:
# time: 110 ms (started: 2022-10-11 23:30:21 +08:00)

# %%
# check shape
df_reportdate.shape
# Out:
# (41032, 4)
# time: 0 ns (started: 2022-10-11 23:30:21 +08:00)

# %%
df_reportdate.notnull().sum()
# Out:
# Ticker         41032
# Report Date    41032
# Open           39777
# Volume         39791
# dtype: int64
# time: 15 ms (started: 2022-10-11 23:30:21 +08:00)

# %%
df_merged.shape
# Out:
# (41032, 74)
# time: 0 ns (started: 2022-10-11 23:30:21 +08:00)

# %% [markdown]
# ## We also want to find out the stock price one year later to be able to measure performance.

# %%
df_reportdate['DaysLater365'] = df_reportdate['Report Date'] + pd.Timedelta(days=365)

# Adding two more columns just in case 365 days later, it is not a trading day
df_reportdate['DaysLater366'] = df_reportdate['Report Date'] + pd.Timedelta(days=366)
df_reportdate['DaysLater367'] = df_reportdate['Report Date'] + pd.Timedelta(days=367)
df_reportdate['DaysLater368'] = df_reportdate['Report Date'] + pd.Timedelta(days=368)
df_reportdate['DaysLater369'] = df_reportdate['Report Date'] + pd.Timedelta(days=369)
# Out:
# time: 15 ms (started: 2022-10-11 23:30:21 +08:00)

# %%
df_reportdate
# Out:
#       Ticker Report Date   Open     Volume DaysLater365 DaysLater366  \
# 0          A  2016-10-31  43.33  1556762.0   2017-10-31   2017-11-01
# 1          A  2017-01-31  48.04  2552612.0   2018-01-31   2018-02-01
# 2          A  2017-04-30  55.50  1897018.0   2018-04-30   2018-05-01
# 3          A  2017-07-31  60.32  1038744.0   2018-07-31   2018-08-01
# 4          A  2017-10-31  67.74  1609938.0   2018-10-31   2018-11-01
# ...      ...         ...    ...        ...          ...          ...
# 41027   ZYXI  2020-09-30  15.55  1115434.0   2021-09-30   2021-10-01
# 41028   ZYXI  2020-12-31  12.71   318435.0   2021-12-31   2022-01-01
# 41029   ZYXI  2021-03-31  13.60   423240.0   2022-03-31   2022-04-01
# 41030   ZYXI  2021-06-30  14.13   144577.0   2022-06-30   2022-07-01
# 41031   ZYXI  2021-09-30  10.58   252514.0   2022-09-30   2022-10-01
#
#       DaysLater367 DaysLater368 DaysLater369
# 0       2017-11-02   2017-11-03   2017-11-04
# 1       2018-02-02   2018-02-03   2018-02-04
# 2       2018-05-02   2018-05-03   2018-05-04
# 3       2018-08-02   2018-08-03   2018-08-04
# 4       2018-11-02   2018-11-03   2018-11-04
# ...            ...          ...          ...
# 41027   2021-10-02   2021-10-03   2021-10-04
# 41028   2022-01-02   2022-01-03   2022-01-04
# 41029   2022-04-02   2022-04-03   2022-04-04
# 41030   2022-07-02   2022-07-03   2022-07-04
# 41031   2022-10-02   2022-10-03   2022-10-04
#
# [41032 rows x 9 columns]
# time: 15 ms (started: 2022-10-11 23:30:21 +08:00)

# %%
# Do something similar to get the price data one year later through merging of the datasets
df_datatwodates365 = pd.merge(df_reportdate, df_price_date, how='left',
                                left_on=['Ticker','DaysLater365'], right_on=['Ticker','Date'])

# get price and volume info from 366, 367, 368 and 369 days later
df_datatwodates366 = pd.merge(df_datatwodates365, df_price_date, how='left',
                                left_on=['Ticker','DaysLater366'], right_on=['Ticker','Date'])

df_datatwodates367 = pd.merge(df_datatwodates366, df_price_date, how='left',
                                left_on=['Ticker','DaysLater367'], right_on=['Ticker','Date'])

df_datatwodates368 = pd.merge(df_datatwodates367, df_price_date, how='left',
                                left_on=['Ticker','DaysLater368'], right_on=['Ticker','Date'])

df_datatwodates369 = pd.merge(df_datatwodates368, df_price_date, how='left',
                                left_on=['Ticker','DaysLater369'], right_on=['Ticker','Date'])
# Out:
# time: 2.86 s (started: 2022-10-11 23:30:21 +08:00)

# %%
# Again, there are some missing price and volume info in the first "Open" and "Volume" column
df_datatwodates369.head(20)
# Out:
#    Ticker Report Date  Open_x   Volume_x DaysLater365 DaysLater366  \
# 0       A  2016-10-31   43.33  1556762.0   2017-10-31   2017-11-01
# 1       A  2017-01-31   48.04  2552612.0   2018-01-31   2018-02-01
# 2       A  2017-04-30   55.50  1897018.0   2018-04-30   2018-05-01
# 3       A  2017-07-31   60.32  1038744.0   2018-07-31   2018-08-01
# 4       A  2017-10-31   67.74  1609938.0   2018-10-31   2018-11-01
# 5       A  2018-01-31   73.77  1949108.0   2019-01-31   2019-02-01
# 6       A  2018-04-30   66.49  2277705.0   2019-04-30   2019-05-01
# 7       A  2018-07-31   64.93  2539265.0   2019-07-31   2019-08-01
# 8       A  2018-10-31   64.35  3820987.0   2019-10-31   2019-11-01
# 9       A  2019-01-31   75.21  2951321.0   2020-01-31   2020-02-01
# 10      A  2019-04-30   77.44  1726239.0   2020-04-29   2020-04-30
# 11      A  2019-07-31   70.19  3846063.0   2020-07-30   2020-07-31
# 12      A  2019-10-31   76.00   970472.0   2020-10-30   2020-10-31
# 13      A  2020-01-31   84.03  2850446.0   2021-01-30   2021-01-31
# 14      A  2020-04-30   77.96  1795163.0   2021-04-30   2021-05-01
# 15      A  2020-07-31   95.94  1551785.0   2021-07-31   2021-08-01
# 16      A  2020-10-31  103.52  1572506.0   2021-10-31   2021-11-01
# 17      A  2021-01-31  120.69  1292732.0   2022-01-31   2022-02-01
# 18      A  2021-04-30  133.90  1514162.0   2022-04-30   2022-05-01
# 19      A  2021-07-31  154.05  1438321.0   2022-07-31   2022-08-01
#
#    DaysLater367 DaysLater368 DaysLater369     Date_x  Open_y   Volume_y  \
# 0    2017-11-02   2017-11-03   2017-11-04 2017-10-31   67.74  1609938.0
# 1    2018-02-02   2018-02-03   2018-02-04 2018-01-31   73.77  1949108.0
# 2    2018-05-02   2018-05-03   2018-05-04 2018-04-30   66.49  2277705.0
# 3    2018-08-02   2018-08-03   2018-08-04 2018-07-31   64.93  2539265.0
# 4    2018-11-02   2018-11-03   2018-11-04 2018-10-31   64.35  3820987.0
# 5    2019-02-02   2019-02-03   2019-02-04 2019-01-31   75.21  2951321.0
# 6    2019-05-02   2019-05-03   2019-05-04 2019-04-30   77.44  1726239.0
# 7    2019-08-02   2019-08-03   2019-08-04 2019-07-31   70.19  3846063.0
# 8    2019-11-02   2019-11-03   2019-11-04 2019-10-31   76.00   970472.0
# 9    2020-02-02   2020-02-03   2020-02-04 2020-01-31   84.03  2850446.0
# 10   2020-05-01   2020-05-02   2020-05-03 2020-04-29   76.30  2409376.0
# 11   2020-08-01   2020-08-02   2020-08-03 2020-07-30   96.12  1663364.0
# 12   2020-11-01   2020-11-02   2020-11-03 2020-10-30  101.77  2310001.0
# 13   2021-02-01   2021-02-02   2021-02-03        NaT     NaN        NaN
# 14   2021-05-02   2021-05-03   2021-05-04 2021-04-30  133.90  1514162.0
# 15   2021-08-02   2021-08-03   2021-08-04        NaT     NaN        NaN
# 16   2021-11-02   2021-11-03   2021-11-04        NaT     NaN        NaN
# 17   2022-02-02   2022-02-03   2022-02-04        NaT     NaN        NaN
# 18   2022-05-02   2022-05-03   2022-05-04        NaT     NaN        NaN
# 19   2022-08-02   2022-08-03   2022-08-04        NaT     NaN        NaN
#
#        Date_y  Open_x   Volume_x     Date_x  Open_y   Volume_y     Date_y  \
# 0  2017-11-01   68.20  1357307.0 2017-11-02   68.08  1854678.0 2017-11-03
# 1  2018-02-01   73.18  1978455.0 2018-02-02   72.32  1947113.0        NaT
# 2  2018-05-01   65.63  3135146.0 2018-05-02   66.00  2240482.0 2018-05-03
# 3  2018-08-01   65.84  2679180.0 2018-08-02   64.75  2263190.0 2018-08-03
# 4  2018-11-01   65.07  1882438.0 2018-11-02   65.80  2272114.0        NaT
# 5  2019-02-01   76.16  1343915.0        NaT     NaN        NaN        NaT
# 6  2019-05-01   78.49  1078572.0 2019-05-02   77.41   946764.0 2019-05-03
# 7  2019-08-01   69.63  2494123.0 2019-08-02   69.12  2803508.0        NaT
# 8  2019-11-01   76.51  1106264.0        NaT     NaN        NaN        NaT
# 9         NaT     NaN        NaN        NaT     NaN        NaN 2020-02-03
# 10 2020-04-30   77.96  1795163.0 2020-05-01   75.55  1618594.0        NaT
# 11 2020-07-31   95.94  1551785.0        NaT     NaN        NaN        NaT
# 12        NaT     NaN        NaN        NaT     NaN        NaN 2020-11-02
# 13        NaT     NaN        NaN 2021-02-01  120.69  1292732.0 2021-02-02
# 14        NaT     NaN        NaN        NaT     NaN        NaN 2021-05-03
# 15        NaT     NaN        NaN 2021-08-02  154.05  1438321.0 2021-08-03
# 16        NaT     NaN        NaN        NaT     NaN        NaN        NaT
# 17        NaT     NaN        NaN        NaT     NaN        NaN        NaT
# 18        NaT     NaN        NaN        NaT     NaN        NaN        NaT
# 19        NaT     NaN        NaN        NaT     NaN        NaN        NaT
#
#     Open_x   Volume_x       Date  Open_y   Volume_y
# 0    68.09  1070662.0        NaT     NaN        NaN
# 1      NaN        NaN        NaT     NaN        NaN
# 2    65.77  2365851.0 2018-05-04   66.03  1331017.0
# 3    65.50  1857308.0        NaT     NaN        NaN
# 4      NaN        NaN        NaT     NaN        NaN
# 5      NaN        NaN 2019-02-04   76.18  2245893.0
# 6    78.58  1303198.0        NaT     NaN        NaN
# 7      NaN        NaN        NaT     NaN        NaN
# 8      NaN        NaN 2019-11-04   77.68  1010174.0
# 9    83.29  1919771.0 2020-02-04   82.85  1676020.0
# 10     NaN        NaN        NaT     NaN        NaN
# 11     NaN        NaN 2020-08-03   96.94  1994325.0
# 12  103.52  1572506.0 2020-11-03  106.43  1175149.0
# 13  122.50  1429186.0 2021-02-03  123.50  1448494.0
# 14  134.29  1032021.0 2021-05-04  132.12  1752428.0
# 15  153.71  1859655.0 2021-08-04  153.96  1786735.0
# 16     NaN        NaN        NaT     NaN        NaN
# 17     NaN        NaN        NaT     NaN        NaN
# 18     NaN        NaN        NaT     NaN        NaN
# 19     NaN        NaN        NaT     NaN        NaN
# time: 15 ms (started: 2022-10-11 23:30:24 +08:00)

# %%
for i in range(1,5):
    df_datatwodates369.iloc[:,10] = np.where(df_datatwodates369.iloc[:,10].isnull(),
                                               df_datatwodates369.iloc[:,10+i*3],
                                               df_datatwodates369.iloc[:,10])
    
    df_datatwodates369.iloc[:,11] = np.where(df_datatwodates369.iloc[:,11].isnull(),
                                               df_datatwodates369.iloc[:,11+i*3],
                                               df_datatwodates369.iloc[:,11])
    i+=1
# Out:
# time: 16 ms (started: 2022-10-11 23:30:24 +08:00)

# %%
df_datatwodates369.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41032 entries, 0 to 41031
# Data columns (total 24 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ticker        41032 non-null  object
#  1   Report Date   41032 non-null  datetime64[ns]
#  2   Open_x        39777 non-null  float64
#  3   Volume_x      39791 non-null  float64
#  4   DaysLater365  41032 non-null  datetime64[ns]
#  5   DaysLater366  41032 non-null  datetime64[ns]
#  6   DaysLater367  41032 non-null  datetime64[ns]
#  7   DaysLater368  41032 non-null  datetime64[ns]
#  8   DaysLater369  41032 non-null  datetime64[ns]
#  9   Date_x        20252 non-null  datetime64[ns]
#  10  Open_y        31066 non-null  float64
#  11  Volume_y      31080 non-null  float64
#  12  Date_y        21344 non-null  datetime64[ns]
#  13  Open_x        21338 non-null  float64
#  14  Volume_x      21344 non-null  float64
#  15  Date_x        24184 non-null  datetime64[ns]
#  16  Open_y        24169 non-null  float64
#  17  Volume_y      24184 non-null  float64
#  18  Date_y        22548 non-null  datetime64[ns]
#  19  Open_x        22536 non-null  float64
#  20  Volume_x      22548 non-null  float64
#  21  Date          16053 non-null  datetime64[ns]
#  22  Open_y        16042 non-null  float64
#  23  Volume_y      16053 non-null  float64
# dtypes: datetime64[ns](11), float64(12), object(1)
# memory usage: 7.8+ MB
# time: 46 ms (started: 2022-10-11 23:30:24 +08:00)

# %%
# Drop off all unnecessary columns first
# Or rather keep all the necessary columns
df_datatwodates = df_datatwodates369.iloc[:,[0,1,2,3,4,10,11]]
df_datatwodates
# Out:
#       Ticker Report Date  Open_x   Volume_x DaysLater365  Open_y   Volume_y
# 0          A  2016-10-31   43.33  1556762.0   2017-10-31   67.74  1609938.0
# 1          A  2017-01-31   48.04  2552612.0   2018-01-31   73.77  1949108.0
# 2          A  2017-04-30   55.50  1897018.0   2018-04-30   66.49  2277705.0
# 3          A  2017-07-31   60.32  1038744.0   2018-07-31   64.93  2539265.0
# 4          A  2017-10-31   67.74  1609938.0   2018-10-31   64.35  3820987.0
# ...      ...         ...     ...        ...          ...     ...        ...
# 41027   ZYXI  2020-09-30   15.55  1115434.0   2021-09-30   10.58   252514.0
# 41028   ZYXI  2020-12-31   12.71   318435.0   2021-12-31     NaN        NaN
# 41029   ZYXI  2021-03-31   13.60   423240.0   2022-03-31     NaN        NaN
# 41030   ZYXI  2021-06-30   14.13   144577.0   2022-06-30     NaN        NaN
# 41031   ZYXI  2021-09-30   10.58   252514.0   2022-09-30     NaN        NaN
#
# [41032 rows x 7 columns]
# time: 16 ms (started: 2022-10-11 23:30:24 +08:00)

# %% [markdown]
# We only draw data from a 5-year range between Oct 2016 to Oct 2021. So we can see that there are some data misssing for price data one year later in the Open_y and Volume_y columns.

# %%
df_datatwodates = df_datatwodates.rename(columns={'Open_x':'Open1',
                                                  'Volume_x':'Volume1',
                                                  'Open_y':'Open2',
                                                  'Volume_y':'Volume2',
                                                  'Report Date':'Date1',
                                                  'DaysLater365':'Date2'})
# Out:
# time: 0 ns (started: 2022-10-11 23:30:24 +08:00)

# %%
df_datatwodates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41032 entries, 0 to 41031
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ticker   41032 non-null  object
#  1   Date1    41032 non-null  datetime64[ns]
#  2   Open1    39777 non-null  float64
#  3   Volume1  39791 non-null  float64
#  4   Date2    41032 non-null  datetime64[ns]
#  5   Open2    31066 non-null  float64
#  6   Volume2  31080 non-null  float64
# dtypes: datetime64[ns](2), float64(4), object(1)
# memory usage: 2.5+ MB
# time: 0 ns (started: 2022-10-11 23:30:25 +08:00)

# %%
df_datatwodates[df_datatwodates.isnull().any(axis=1)]
# Out:
#       Ticker      Date1   Open1    Volume1      Date2  Open2  Volume2
# 16         A 2020-10-31  103.52  1572506.0 2021-10-31    NaN      NaN
# 17         A 2021-01-31  120.69  1292732.0 2022-01-31    NaN      NaN
# 18         A 2021-04-30  133.90  1514162.0 2022-04-30    NaN      NaN
# 19         A 2021-07-31  154.05  1438321.0 2022-07-31    NaN      NaN
# 36        AA 2020-12-31   23.00  3443724.0 2021-12-31    NaN      NaN
# ...      ...        ...     ...        ...        ...    ...      ...
# 41012   ZYNE 2021-09-30    4.25   761190.0 2022-09-30    NaN      NaN
# 41028   ZYXI 2020-12-31   12.71   318435.0 2021-12-31    NaN      NaN
# 41029   ZYXI 2021-03-31   13.60   423240.0 2022-03-31    NaN      NaN
# 41030   ZYXI 2021-06-30   14.13   144577.0 2022-06-30    NaN      NaN
# 41031   ZYXI 2021-09-30   10.58   252514.0 2022-09-30    NaN      NaN
#
# [10284 rows x 7 columns]
# time: 15 ms (started: 2022-10-11 23:30:25 +08:00)

# %% [markdown]
# # Saving our files to csv

# %%
# We save df_datatwodates as y first (total 41,032 rows), even though it has some null values
y = df_datatwodates
y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41032 entries, 0 to 41031
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ticker   41032 non-null  object
#  1   Date1    41032 non-null  datetime64[ns]
#  2   Open1    39777 non-null  float64
#  3   Volume1  39791 non-null  float64
#  4   Date2    41032 non-null  datetime64[ns]
#  5   Open2    31066 non-null  float64
#  6   Volume2  31080 non-null  float64
# dtypes: datetime64[ns](2), float64(4), object(1)
# memory usage: 2.5+ MB
# time: 15 ms (started: 2022-10-11 23:30:25 +08:00)

# %%
# We also save df_merged as our x dataframe (total 41,032 rows), so it contains all our fundamental data.
x = df_merged
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41032 entries, 0 to 41031
# Data columns (total 74 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Ticker                                           41032 non-null  object
#  1   Report Date                                      41032 non-null  datetime64[ns]
#  2   SimFinId                                         41032 non-null  int64
#  3   Currency                                         41032 non-null  object
#  4   Fiscal Year                                      41032 non-null  int64
#  5   Fiscal Period_x                                  41032 non-null  object
#  6   Publish Date                                     41032 non-null  datetime64[ns]
#  7   Restated Date_x                                  41032 non-null  datetime64[ns]
#  8   Shares (Basic)_x                                 40540 non-null  float64
#  9   Shares (Diluted)_x                               40540 non-null  float64
#  10  Revenue                                          39823 non-null  float64
#  11  Cost of Revenue                                  36646 non-null  float64
#  12  Gross Profit                                     36616 non-null  float64
#  13  Operating Expenses                               40977 non-null  float64
#  14  Selling, General & Administrative                39007 non-null  float64
#  15  Research & Development                           17527 non-null  float64
#  16  Depreciation & Amortization_x                    18331 non-null  float64
#  17  Operating Income (Loss)                          41031 non-null  float64
#  18  Non-Operating Income (Loss)                      40797 non-null  float64
#  19  Interest Expense, Net                            36692 non-null  float64
#  20  Pretax Income (Loss), Adj.                       41032 non-null  int64
#  21  Abnormal Gains (Losses)                          23794 non-null  float64
#  22  Pretax Income (Loss)                             41032 non-null  int64
#  23  Income Tax (Expense) Benefit, Net                37006 non-null  float64
#  24  Income (Loss) from Continuing Operations         41032 non-null  int64
#  25  Net Extraordinary Gains (Losses)                 4859 non-null   float64
#  26  Net Income                                       41032 non-null  int64
#  27  Net Income (Common)                              41032 non-null  int64
#  28  Fiscal Period_y                                  41032 non-null  object
#  29  Restated Date_y                                  41032 non-null  datetime64[ns]
#  30  Shares (Basic)_y                                 40540 non-null  float64
#  31  Shares (Diluted)_y                               40540 non-null  float64
#  32  Cash, Cash Equivalents & Short Term Investments  40906 non-null  float64
#  33  Accounts & Notes Receivable                      36877 non-null  float64
#  34  Inventories                                      26929 non-null  float64
#  35  Total Current Assets                             41031 non-null  float64
#  36  Property, Plant & Equipment, Net                 40283 non-null  float64
#  37  Long Term Investments & Receivables              10429 non-null  float64
#  38  Other Long Term Assets                           40618 non-null  float64
#  39  Total Noncurrent Assets                          40930 non-null  float64
#  40  Total Assets                                     41032 non-null  int64
#  41  Payables & Accruals                              40880 non-null  float64
#  42  Short Term Debt                                  25717 non-null  float64
#  43  Total Current Liabilities                        41032 non-null  int64
#  44  Long Term Debt                                   32521 non-null  float64
#  45  Total Noncurrent Liabilities                     40444 non-null  float64
#  46  Total Liabilities                                41032 non-null  int64
#  47  Share Capital & Additional Paid-In Capital       40447 non-null  float64
#  48  Treasury Stock                                   17759 non-null  float64
#  49  Retained Earnings                                39117 non-null  float64
#  50  Total Equity                                     41030 non-null  float64
#  51  Total Liabilities & Equity                       41032 non-null  int64
#  52  Fiscal Period                                    41032 non-null  object
#  53  Restated Date                                    41032 non-null  datetime64[ns]
#  54  Shares (Basic)                                   40540 non-null  float64
#  55  Shares (Diluted)                                 40540 non-null  float64
#  56  Net Income/Starting Line                         40521 non-null  float64
#  57  Depreciation & Amortization_y                    39927 non-null  float64
#  58  Non-Cash Items                                   40491 non-null  float64
#  59  Change in Working Capital                        40304 non-null  float64
#  60  Change in Accounts Receivable                    2859 non-null   float64
#  61  Change in Inventories                            2068 non-null   float64
#  62  Change in Accounts Payable                       2318 non-null   float64
#  63  Change in Other                                  3401 non-null   float64
#  64  Net Cash from Operating Activities               41030 non-null  float64
#  65  Change in Fixed Assets & Intangibles             39900 non-null  float64
#  66  Net Change in Long Term Investment               14584 non-null  float64
#  67  Net Cash from Acquisitions & Divestitures        18049 non-null  float64
#  68  Net Cash from Investing Activities               40720 non-null  float64
#  69  Dividends Paid                                   18740 non-null  float64
#  70  Cash from (Repayment of) Debt                    34026 non-null  float64
#  71  Cash from (Repurchase of) Equity                 33302 non-null  float64
#  72  Net Cash from Financing Activities               40756 non-null  float64
#  73  Net Change in Cash                               41032 non-null  int64
# dtypes: datetime64[ns](5), float64(52), int64(12), object(5)
# memory usage: 23.2+ MB
# time: 94 ms (started: 2022-10-11 23:30:25 +08:00)

# %%
# save the final file to csv
x.to_csv("./data/01_fundamentals.csv")
y.to_csv("./data/01_pricedata.csv")
# Out:
# time: 3.25 s (started: 2022-10-11 23:30:25 +08:00)

# %%
pickle.dump(x, open('./data/01_fundamentals.pkl', 'wb'))
pickle.dump(y, open('./data/01_pricedata.pkl', 'wb'))
# Out:
# time: 31 ms (started: 2022-10-11 23:30:28 +08:00)
